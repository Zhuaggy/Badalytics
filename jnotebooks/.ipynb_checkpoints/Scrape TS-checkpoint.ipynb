# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from tqdm import tqdm

# %% [markdown]
# ## International Matches from tournament software

# %%
Tournament_match_links = ['https://bwf.tournamentsoftware.com/sport/matches.aspx?id=33F2CE56-0C0B-4DCD-9541-EAB40F8AB558',
                         'https://bwf.tournamentsoftware.com/sport/matches.aspx?id=33F2CE56-0C0B-4DCD-9541-EAB40F8AB558&d=20180411',
                         'https://bwf.tournamentsoftware.com/sport/matches.aspx?id=33F2CE56-0C0B-4DCD-9541-EAB40F8AB558&d=20180412',
                         'https://bwf.tournamentsoftware.com/sport/matches.aspx?id=33F2CE56-0C0B-4DCD-9541-EAB40F8AB558&d=20180413',
                         'https://bwf.tournamentsoftware.com/sport/matches.aspx?id=33F2CE56-0C0B-4DCD-9541-EAB40F8AB558&d=20180414',
                         'https://bwf.tournamentsoftware.com/sport/matches.aspx?id=33F2CE56-0C0B-4DCD-9541-EAB40F8AB558&d=20180415']
Tournament_Name = 'Indonesia International Series 2018'
Tournament_Date = '20180410'

# %%
#Lists to append
player_list = []
score_list = []
event_list = []
country_list = []

for url in Tournament_match_links:
    #Get page session
    r_obj = requests.Session()
    fr_soup = r_obj.get(url)
    soup = BeautifulSoup(fr_soup.content , "lxml")
    detail_tab = soup.find_all("tbody")
    detail_tab = detail_tab[0].find_all("tr")
    
    #Loop through the rows of table
    for row in tqdm(detail_tab):
        if len(row) == 13:
            player_rows = row.find_all('a', href=re.compile('^player'))
            players = []
            for player in player_rows:
                players.append(player.contents[0])
            player_list.append(players)
            
            #Check if score is there
            if row.find_all('span', {'class' : 'score'}):
                score_rows = row.find_all('span', {'class' : 'score'})[0].find_all('span')
                scores = []
                for score in score_rows:
                    scores.append(score.contents[0])
                score_list.append(scores)
            else:
                score_list.append([])
            
            country_rows = row.find_all('span', {'class' : 'printonly flag'})
            countries = []
            for country in country_rows:
                countries.append(country.contents[0])
            country_list.append(countries)

            event_list.append(row.find_all('a', href=re.compile('draw'))[0].contents[0])    
    
    #Close session
    r_obj.close()
    
df = pd.DataFrame()
df['PLAYERS'] = player_list
df['COUNTRIES'] = country_list
df['SCORES'] = score_list
df['EVENT'] = event_list
df['match_week'] = [Tournament_Date]*len(df)

df.to_csv('2018 Tournaments/' + str(Tournament_Name) + '_' + str(Tournament_Date) + '.csv')
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 1459.11it/s]
# 100%|██████████| 331/331 [00:00<00:00, 1640.39it/s]
# 100%|██████████| 168/168 [00:00<00:00, 1612.75it/s]
# 100%|██████████| 88/88 [00:00<00:00, 1769.42it/s]
# 100%|██████████| 44/44 [00:00<00:00, 1748.04it/s]
# 100%|██████████| 22/22 [00:00<00:00, 1656.99it/s]

# %%
r_obj.close()

# %%
if row.find_all('span', {'class' : 'score'}):
    print ('hi')
# Out:
# hi

# %%
df = pd.DataFrame()
df['PLAYERS'] = player_list
df['COUNTRIES'] = country_list
df['SCORES'] = score_list
df['EVENT'] = event_list
df['match_week'] = [Tournament_Date]*len(df)

df.to_csv('2018 Tournaments/' + str(Tournament_Name) + '_' + str(Tournament_Date) + '.csv')

# %%
Tournament_Name
# Out:
# 'Estonian_International_2018'

# %% [markdown]
# ## For just one page

# %%
r_obj = requests.Session()
url = "https://bwf.tournamentsoftware.com/sport/matches.aspx?id=A03A06FB-E57B-487D-8866-ADC83F07997F&d=20170614"
fr_soup = r_obj.get(url)
soup = BeautifulSoup(fr_soup.content , "lxml")

# %%
detail_tab = soup.find_all("tbody")
detail_tab = detail_tab[0].find_all("tr")

# %%
#Lists to append
player_list = []
score_list = []
event_list = []
country_list = []

for row in tqdm(detail_tab):
    if len(row) == 13:
        player_rows = row.find_all('a', href=re.compile('^player'))
        players = []
        for player in player_rows:
            players.append(player.contents[0])
        player_list.append(players)
        
        score_rows = row.find_all('span', {'class' : 'score'})[0].find_all('span')
        scores = []
        for score in score_rows:
            scores.append(score.contents[0])
        score_list.append(scores)
        
        country_rows = row.find_all('span', {'class' : 'printonly flag'})
        countries = []
        for country in country_rows:
            countries.append(country.contents[0])
        country_list.append(countries)
        
        event_list.append(row.find_all('a', href=re.compile('draw'))[0].contents[0])
# Out:
# 100%|██████████| 203/203 [00:00<00:00, 2107.19it/s]

# %%
df = pd.DataFrame()
df['PLAYERS'] = player_list
df['COUNTRIES'] = country_list
df['SCORES'] = score_list
df['EVENT'] = event_list

# %%
df
# Out:
#                                               PLAYERS  \
# 0   [Huang Yaqiong, Yu Xiaohan, Misaki Matsutomo [...
# 1   [Kim Astrup, Anders Skaarup Rasmussen, Marcus ...
# 2   [Yuki Fukushima, Sayaka Hirota, Serena Kani, J...
# 3      [Liu Cheng, Zhang Nan, Ong Yew Sin, Teo Ee Yi]
# 4   [Shiho Tanaka [8], Koharu Yonemoto, Yin Loo Li...
# 5   [Naoko Fukuman, Kurumi Yonao, Keshya Nurvita H...
# 6   [Chang Ye Na [3], Lee So Hee, Maiken Fruergaar...
# 7   [Takeshi Kamura [6], Keigo Sonoda, Chen Hung L...
# 8   [Greysia Polii, Apriyani Rahayu, Chae Yoo Jung...
# 9   [Mathias Christiansen, David Daugaard, Takuro ...
# 10  [Luo Ying [6], Luo Yu, Agatha Imanuela, Siti F...
# 11  [Della Destiara Haris, Rosyita Eka Putri Sari,...
# 12  [Puttita Supajirakul, Sapsiree Taerattanachai,...
# 13  [Li Junhui [3], Liu Yuchen, Or Chin Chung, Tan...
# 14  [Anggia Shitta Awanda, Ni Ketut Mahadewi Istar...
# 15  [Hendra Setiawan, Boon Heong Tan, Hiroyuki End...
# 16  [Jung Kyung Eun [4], Shin Seung Chan, Bao Yixi...
# 17  [Chai Biao [5], Hong Wei, Danny Bawa Chrisnant...
# 18  [Ricky Karandasuwardi [8], Angga Pratama, Akba...
# 19  [Lee Jhe-Huei, Lee Yang, Law Cheuk Him, Lee Ch...
# 20  [Fajar Alfian, Muhammad Rian Ardianto, Satwiks...
# 21  [Kittinupong Kedren, Dechapol Puavaranukroh, M...
# 22                [Lee Chong Wei [1], Tommy Sugiarto]
# 23  [Hendra Aprida Gunawan, Markis Kido, Lu Kai, Z...
# 24                      [Zhao Junpeng, Huang Yuxiang]
# 25          [Prannoy H. S., Anthony Sinisuka Ginting]
# 26                     [Chen Long [8], Marc Zwiebler]
# 27                  [Son Wan Ho [2], Sai Praneeth B.]
# 28                    [Jonatan Christie, Hsu Jen Hao]
# 29  [Dian Fitriani, Nadya Melati, Ashwini Ponnappa...
# 30  [Chen Qingchen [5], Jia Yifan, Chow Mei Kuan, ...
# 31                   [Emil Holst, Viktor Axelsen [3]]
# 32                        [Shi Yuqi [5], Lee Hyun Il]
# 33                   [Kazumasa Sakai, Wei Feng Chong]
# 34  [Vladimir Ivanov, Ivan Sozonov, Mads Conrad-Pe...
# 35  [Poon Lok Yan, Tse Ying Suet, Vivian Hoo, Woon...
# 36  [Kamilla Rytter Juhl [2], Christinna Pedersen,...
# 37           [Rajiv Ouseph, Tanongsak Saensomboonsuk]
# 38  [Lu Ching Yao, Yang Po Han, Sze Fei Goh, Nur I...
# 39                        [Tzu Wei Wang, Lin Dan [7]]
# 40                    [Ng Ka Long Angus, Tian Houwei]
# 41           [Kidambi Srikanth, Wong Wing Ki Vincent]
# 42  [Mathias Boe [2], Carsten Mogensen, Berry Angr...
# 43              [Jan O Jorgensen [4], Brice Leverdez]
# 44  [Chou Tien Chen [6], Hans-Kristian Solberg Vit...
# 45                          [Anders Antonsen, Hu Yun]
# 46  [Bodin Isara, Nipitphon Phuangphuapet, Calvin ...
#
#                            COUNTRIES                 SCORES EVENT
# 0   [[CHN] , [CHN] , [JPN] , [JPN] ]          [21-7, 22-20]    WD
# 1   [[DEN] , [DEN] , [INA] , [INA] ]         [21-16, 21-16]    MD
# 2   [[JPN] , [JPN] , [INA] , [INA] ]         [21-10, 21-14]    WD
# 3   [[CHN] , [CHN] , [MAS] , [MAS] ]         [21-17, 21-12]    MD
# 4   [[JPN] , [JPN] , [MAS] , [MAS] ]  [21-18, 14-21, 21-12]    WD
# 5   [[JPN] , [JPN] , [INA] , [INA] ]         [21-10, 21-14]    WD
# 6   [[KOR] , [KOR] , [DEN] , [DEN] ]         [21-14, 21-13]    WD
# 7   [[JPN] , [JPN] , [TPE] , [TPE] ]         [21-18, 14-10]    MD
# 8   [[INA] , [INA] , [KOR] , [KOR] ]  [15-21, 25-23, 21-14]    WD
# 9   [[DEN] , [DEN] , [JPN] , [JPN] ]         [21-16, 21-13]    MD
# 10  [[CHN] , [CHN] , [INA] , [INA] ]  [13-21, 21-10, 21-19]    WD
# 11  [[INA] , [INA] , [AUS] , [AUS] ]         [21-11, 21-13]    WD
# 12  [[THA] , [THA] , [INA] , [INA] ]         [21-16, 21-15]    WD
# 13  [[CHN] , [CHN] , [HKG] , [HKG] ]         [21-18, 21-13]    MD
# 14  [[INA] , [INA] , [INA] , [INA] ]  [23-21, 18-21, 21-15]    WD
# 15  [[INA] , [MAS] , [JPN] , [JPN] ]  [10-21, 26-24, 23-21]    MD
# 16  [[KOR] , [KOR] , [CHN] , [CHN] ]         [23-21, 21-13]    WD
# 17  [[CHN] , [CHN] , [SGP] , [SGP] ]  [21-18, 15-21, 21-12]    MD
# 18  [[INA] , [INA] , [INA] , [INA] ]         [21-17, 21-18]    MD
# 19  [[TPE] , [TPE] , [HKG] , [HKG] ]         [21-16, 21-12]    MD
# 20  [[INA] , [INA] , [IND] , [IND] ]          [21-9, 21-19]    MD
# 21  [[THA] , [THA] , [INA] , [INA] ]  [21-19, 17-21, 21-18]    MD
# 22                  [[MAS] , [INA] ]  [13-21, 21-10, 21-18]    MS
# 23  [[INA] , [INA] , [CHN] , [CHN] ]                     []    MD
# 24                  [[CHN] , [CHN] ]         [21-15, 21-19]    MS
# 25                  [[IND] , [INA] ]         [21-13, 21-18]    MS
# 26                  [[CHN] , [GER] ]         [21-14, 21-14]    MS
# 27                  [[KOR] , [IND] ]         [21-14, 21-18]    MS
# 28                  [[INA] , [TPE] ]         [21-17, 21-15]    MS
# 29  [[INA] , [INA] , [IND] , [IND] ]  [19-21, 21-19, 21-13]    WD
# 30  [[CHN] , [CHN] , [MAS] , [MAS] ]  [22-20, 13-21, 21-14]    WD
# 31                  [[DEN] , [DEN] ]  [21-12, 12-21, 21-17]    MS
# 32                  [[CHN] , [KOR] ]         [21-18, 21-12]    MS
# 33                  [[JPN] , [MAS] ]          [21-18, 21-8]    MS
# 34  [[RUS] , [RUS] , [DEN] , [DEN] ]  [21-16, 10-21, 22-20]    MD
# 35  [[HKG] , [HKG] , [MAS] , [MAS] ]          [21-9, 21-12]    WD
# 36  [[DEN] , [DEN] , [KOR] , [KOR] ]          [21-16, 21-8]    WD
# 37                  [[ENG] , [THA] ]  [21-13, 12-21, 25-23]    MS
# 38  [[TPE] , [TPE] , [MAS] , [MAS] ]         [21-14, 21-16]    MD
# 39                  [[TPE] , [CHN] ]         [21-16, 21-18]    MS
# 40                  [[HKG] , [CHN] ]  [21-14, 10-21, 21-19]    MS
# 41                  [[IND] , [HKG] ]  [21-15, 17-21, 21-16]    MS
# 42  [[DEN] , [DEN] , [INA] , [INA] ]  [21-18, 21-23, 21-15]    MD
# 43                  [[DEN] , [FRA] ]         [21-16, 21-18]    MS
# 44                  [[TPE] , [DEN] ]         [21-19, 21-12]    MS
# 45                  [[DEN] , [HKG] ]         [21-10, 21-19]    MS
# 46  [[THA] , [THA] , [INA] , [INA] ]         [21-13, 21-12]    MD
