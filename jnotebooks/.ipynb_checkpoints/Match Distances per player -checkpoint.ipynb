# %%
import pandas as pd
from tqdm import tqdm
import re
# %matplotlib inline

# %%
df = pd.read_csv('Match Distances.csv')
del df['Unnamed: 0']

# %%
def convert_to_event(x):
    if 'MS' in x:
        return ('MS')
    elif 'WS' in x:
        return ('WS')
    elif 'WD' in x:
        return ('WD')
    elif 'MD' in x:
        return ('MD')
    elif 'XD' in x:
        return ('XD')

df['EVENT'] = df['EVENT'].apply(lambda x:convert_to_event(x))

# %%
df
# Out:
#                                       COUNTRIES EVENT  \
# 0                          ['[SWE] ', '[GER] ']    MS
# 1                          ['[SUI] ', '[RUS] ']    WS
# 2      ['[RUS] ', '[RUS] ', '[ENG] ', '[ENG] ']    XD
# 3      ['[ENG] ', '[ENG] ', '[NED] ', '[NED] ']    XD
# 4      ['[FRA] ', '[FRA] ', '[NED] ', '[NED] ']    XD
# 5                          ['[RUS] ', '[CZE] ']    MS
# 6      ['[DEN] ', '[DEN] ', '[IRL] ', '[IRL] ']    XD
# 7      ['[DEN] ', '[DEN] ', '[FRA] ', '[FRA] ']    XD
# 8                          ['[GER] ', '[BUL] ']    WS
# 9                          ['[ENG] ', '[FRA] ']    MS
# 10                         ['[ENG] ', '[AUT] ']    MS
# 11     ['[SVK] ', '[SVK] ', '[AUT] ', '[AUT] ']    XD
# 12                         ['[BEL] ', '[HUN] ']    WS
# 13                         ['[HUN] ', '[ITA] ']    MS
# 14                         ['[GER] ', '[FIN] ']    MS
# 15                         ['[CZE] ', '[POR] ']    MS
# 16     ['[NED] ', '[NED] ', '[SUI] ', '[SUI] ']    XD
# 17                         ['[FIN] ', '[SVK] ']    WS
# 18                         ['[SUI] ', '[MDA] ']    MS
# 19     ['[FRA] ', '[FRA] ', '[CZE] ', '[CZE] ']    XD
# 20                         ['[ESP] ', '[CRO] ']    MS
# 21                         ['[UKR] ', '[WAL] ']    WS
# 22                         ['[TUR] ', '[ESP] ']    WS
# 23     ['[DEN] ', '[DEN] ', '[EST] ', '[EST] ']    XD
# 24     ['[GER] ', '[GER] ', '[UKR] ', '[UKR] ']    XD
# 25                         ['[DEN] ', '[AZE] ']    MS
# 26                         ['[ROU] ', '[CYP] ']    MS
# 27                         ['[ENG] ', '[CRO] ']    WS
# 28                         ['[IRL] ', '[ISL] ']    MS
# 29                         ['[GER] ', '[CYP] ']    WS
# ...                                         ...   ...
# 15594                      ['[CHN] ', '[INA] ']    MS
# 15595  ['[TPE] ', '[TPE] ', '[DEN] ', '[DEN] ']    MD
# 15596  ['[CHN] ', '[CHN] ', '[POL] ', '[POL] ']    MD
# 15597  ['[BUL] ', '[BUL] ', '[GER] ', '[GER] ']    WD
# 15598  ['[ENG] ', '[ENG] ', '[DEN] ', '[DEN] ']    MD
# 15599  ['[CHN] ', '[CHN] ', '[THA] ', '[THA] ']    WD
# 15600  ['[CHN] ', '[CHN] ', '[IND] ', '[IND] ']    XD
# 15601  ['[CHN] ', '[CHN] ', '[INA] ', '[INA] ']    MD
# 15602                      ['[INA] ', '[DEN] ']    MS
# 15603  ['[CHN] ', '[CHN] ', '[INA] ', '[INA] ']    WD
# 15604  ['[DEN] ', '[DEN] ', '[MAS] ', '[MAS] ']    WD
# 15605                      ['[CHN] ', '[JPN] ']    WS
# 15606  ['[INA] ', '[INA] ', '[SGP] ', '[SGP] ']    XD
# 15607                      ['[JPN] ', '[BUL] ']    WS
# 15608                      ['[CHN] ', '[IND] ']    MS
# 15609  ['[CHN] ', '[CHN] ', '[DEN] ', '[DEN] ']    WD
# 15610  ['[CHN] ', '[CHN] ', '[TPE] ', '[TPE] ']    MD
# 15611                      ['[CHN] ', '[INA] ']    WS
# 15612  ['[THA] ', '[THA] ', '[CHN] ', '[CHN] ']    XD
# 15613                      ['[CHN] ', '[INA] ']    MS
# 15614  ['[INA] ', '[INA] ', '[CHN] ', '[CHN] ']    XD
# 15615                      ['[CHN] ', '[JPN] ']    WS
# 15616                      ['[CHN] ', '[TPE] ']    MS
# 15617  ['[BUL] ', '[BUL] ', '[CHN] ', '[CHN] ']    WD
# 15618  ['[CHN] ', '[CHN] ', '[ENG] ', '[ENG] ']    MD
# 15619                      ['[CHN] ', '[CHN] ']    WS
# 15620  ['[THA] ', '[THA] ', '[INA] ', '[INA] ']    XD
# 15621  ['[CHN] ', '[CHN] ', '[BUL] ', '[BUL] ']    WD
# 15622  ['[CHN] ', '[CHN] ', '[CHN] ', '[CHN] ']    MD
# 15623                      ['[CHN] ', '[CHN] ']    MS
#
#                                                  PLAYERS  \
# 0                      ['Jacob Nilsson', 'Kai Schaefer']
# 1                ['Sabrina Jaquet', 'Natalia Perminova']
# 2      ['Rodion Alimov', 'Alina Davletova', 'Ben Lane...
# 3      ['Marcus Ellis [3]', 'Lauren Smith', 'Robin Ta...
# 4      ['Bastian Kersaudy', 'Lea Palermo', 'Jelle Maa...
# 5                       ['Sergey Sirant', 'Milan Ludik']
# 6      ['Mathias Christiansen [2]', 'Christinna Peder...
# 7      ['Joachim Fischer Nielsen', 'Alexandra Bøje', ...
# 8                       ['Luise Heim', 'Linda Zetchiri']
# 9                      ['Toby Penty', 'Lucas Claerbout']
# 10                        ['Sam Parsons', 'Luka Wraber']
# 11     ['Milan Dratva', 'Martina Repiska', 'Dominik S...
# 12                        ['Lianne Tan', 'Agnes Korosi']
# 13               ['Gergely Krausz', 'Rosario Maddaloni']
# 14               ['Alexander Roovers', 'Kalle Koljonen']
# 15                  ['Adam Mendrek', 'Duarte Nuno Anjo']
# 16     ['Jacco Arends [4]', 'Selena Piek', 'Oliver Sc...
# 17                   ['Airi Mikkela', 'Martina Repiska']
# 18             ['Christian Kirchmayr', 'Cristian Savin']
# 19     ['Ronan Labar [8]', 'Audrey Fontaine', 'Jakub ...
# 20       ['Luís Enrique Peñalver', 'Zvonimir Durkinjak']
# 21                      ['Maria Ulitina', 'Jordan Hart']
# 22                 ['Aliye Demirbag', 'Clara Azurmendi']
# 23     ['Niclas Nohr', 'Sara Thygesen', 'Sander Merit...
# 24     ['Marvin Emil Seidel [7]', 'Linda Efler', 'Art...
# 25              ['Jan O Jorgensen', 'Orkhan Galandarov']
# 26       ['Collins Valentine Filimon', 'Elias Nicolaou']
# 27                      ['Chloe Birch', 'Maja Pavlinic']
# 28                    ['Nhat Nguyen', 'Kari Gunnarsson']
# 29                  ['Yvonne Li', 'Eleni Christodoulou']
# ...                                                  ...
# 15594      ['Lin Dan [1]', 'Ihsan Maulana Mustofa [15]']
# 15595  ['Chen Hung Ling [5]', 'Chi-Lin Wang', 'Kim As...
# 15596  ['Liu Cheng', 'Zhang Nan', 'Milosz Bochat', 'A...
# 15597  ['Gabriela Stoeva [4]', 'Stefani Stoeva', 'Isa...
# 15598  ['Marcus Ellis [4]', 'Chris Langridge', 'Mathi...
# 15599  ['Bao Yixin', 'Yu Xiaohan', 'Puttita Supajirak...
# 15600  ['Zhang Nan [5]', 'Li Yinhui', 'Pranaav Jerry ...
# 15601  ['Chai Biao [1]', 'Hong Wei', 'Fajar Alfian [8...
# 15602  ['Anthony Sinisuka Ginting [12]', 'Emil Holst ...
# 15603  ['Chen Qingchen [1]', 'Jia Yifan', 'Della Dest...
# 15604  ['Maiken Fruergaard [7]', 'Sara Thygesen', 'Vi...
# 15605             ['Chen Yufei [3]', 'Sayaka Takahashi']
# 15606  ['Praveen Jordan [2]', 'Debby Susanto', 'Yong ...
# 15607            ['Chisato Hoshi', 'Linda Zetchiri [6]']
# 15608              ['Shi Yuqi [2]', 'Prannoy H. S. [5]']
# 15609  ['Chen Qingchen [1]', 'Jia Yifan', 'Maiken Fru...
# 15610  ['Chai Biao [1]', 'Hong Wei', 'Chen Hung Ling ...
# 15611          ['Chen Xiaoxin', 'Fitriani Fitriani [7]']
# 15612  ['Dechapol Puavaranukroh [3]', 'Sapsiree Taera...
# 15613   ['Lin Dan [1]', 'Anthony Sinisuka Ginting [12]']
# 15614  ['Praveen Jordan [2]', 'Debby Susanto', 'Zhang...
# 15615                ['Chen Yufei [3]', 'Chisato Hoshi']
# 15616               ['Shi Yuqi [2]', 'Tzu Wei Wang [6]']
# 15617  ['Gabriela Stoeva [4]', 'Stefani Stoeva', 'Bao...
# 15618  ['Liu Cheng', 'Zhang Nan', 'Marcus Ellis [4]',...
# 15619                 ['Chen Xiaoxin', 'Chen Yufei [3]']
# 15620  ['Dechapol Puavaranukroh [3]', 'Sapsiree Taera...
# 15621  ['Chen Qingchen [1]', 'Jia Yifan', 'Gabriela S...
# 15622  ['Chai Biao [1]', 'Hong Wei', 'Liu Cheng', 'Zh...
# 15623                    ['Lin Dan [1]', 'Shi Yuqi [2]']
#
#                             SCORES      match_location  match_week  \
# 0               ['21-14', '22-20']       Huelva, Spain    20180424
# 1      ['21-17', '13-21', '21-17']       Huelva, Spain    20180424
# 2               ['21-19', '27-25']       Huelva, Spain    20180424
# 3      ['17-21', '21-11', '21-15']       Huelva, Spain    20180424
# 4               ['23-21', '21-12']       Huelva, Spain    20180424
# 15617           ['22-20', '21-19']  Basel, Switzerland    20170314
# 15618            ['21-9', '21-19']  Basel, Switzerland    20170314
# 15619           ['21-19', '21-14']  Basel, Switzerland    20170314
# 15620           ['21-18', '21-15']  Basel, Switzerland    20170314
# 15621           ['21-16', '21-15']  Basel, Switzerland    20170314
# 15622  ['13-21', '21-16', '21-15']  Basel, Switzerland    20170314
# 15623           ['21-12', '21-11']  Basel, Switzerland    20170314
#
#       Winning Country Losing Country  Winning Country Coord_x  \
# 0                 SWE            GER                17.260488
# 1                 SUI            RUS                 8.245024
# 2                 RUS            ENG                96.805372
# 3                 ENG            NED                -1.458628
# 4                 FRA            NED                 2.550540
# 5                 RUS            CZE                96.805372
# 6                 DEN            IRL                10.053934
# 7                 DEN            FRA                10.053934
# 8                 GER            BUL                10.392278
# 9                 ENG            FRA                -1.458628
# 10                ENG            AUT                -1.458628
# 11                SVK            AUT                19.487749
# 12                BEL            HUN                 4.661070
# 13                HUN            ITA                19.424532
# 14                GER            FIN                10.392278
# 15                CZE            POR                15.331770
# 16                NED            SUI                 5.616126
# 17                FIN            SVK                26.158834
# 18                SUI            MDA                 8.245024
# 19                FRA            CZE                 2.550540
# 20                ESP            CRO                -3.646063
# 21                UKR            WAL                31.374926
# 22                TUR            ESP                35.142286
# 23                DEN            EST                10.053934
# 24                GER            UKR                10.392278
# 25                DEN            AZE                10.053934
# 26                ROU            CYP                24.973472
# 27                ENG            CRO                -1.458628
# 28                IRL            ISL                -8.146006
# 29                GER            CYP                10.392278
# ...               ...            ...                      ...
# 15594             CHN            INA               103.930027
# 15595             TPE            DEN               120.953464
# 15596             CHN            POL               103.930027
# 15597             BUL            GER                25.236412
# 15598             ENG            DEN                -1.458628
# 15599             CHN            THA               103.930027
# 15600             CHN            IND               103.930027
# 15601             CHN            INA               103.930027
# 15602             INA            DEN               113.915865
# 15603             CHN            INA               103.930027
# 15604             DEN            MAS                10.053934
# 15605             CHN            JPN               103.930027
# 15606             INA            SGP               113.915865
# 15607             JPN            BUL               139.271495
# 15608             CHN            IND               103.930027
# 15609             CHN            DEN               103.930027
# 15610             CHN            TPE               103.930027
# 15611             CHN            INA               103.930027
# 15612             THA            CHN               101.012239
# 15613             CHN            INA               103.930027
# 15614             INA            CHN               113.915865
# 15615             CHN            JPN               103.930027
# 15616             CHN            TPE               103.930027
# 15617             BUL            CHN                25.236412
# 15618             CHN            ENG               103.930027
# 15619             CHN            CHN               103.930027
# 15620             THA            INA               101.012239
# 15621             CHN            BUL               103.930027
# 15622             CHN            CHN               103.930027
# 15623             CHN            CHN               103.930027
#
#        Winning Country Coord_y  Losing Country Coord_x  \
# 0                    64.712586               10.392278
# 1                    46.799817               96.805372
# 2                    61.989526               -1.458628
# 3                    52.592743                5.616126
# 4                    46.559417                5.616126
# 5                    61.989526               15.331770
# 6                    55.959301               -8.146006
# 7                    55.959301                2.550540
# 8                    51.110631               25.236412
# 9                    52.592743                2.550540
# 10                   52.592743               14.137077
# 11                   48.708702               14.137077
# 15621     10688.116836     2027.945002
# 15622     10688.116836    10688.116836
# 15623     10688.116836    10688.116836
#
# [15624 rows x 16 columns]

# %%
# Get winner and loser columns

def filter_name(string):
    del_chars = ['[',']','1','2','3','4','5','6','7','8','9','0']
    return_string = string
    for char in string:
        if char in del_chars:
            return_string = return_string.replace(char,'')
    
    return_string = return_string.strip()
    return (return_string)

#Take in line, player team you want to extract and singles or doubles
def split_players(x,player_num,s_or_d):
    #Need to filter out using regex
    return_val = re.findall("'(.*?)'",x)
    
    #Singles
    if s_or_d == 's':
        #only if there are two opponents
        if len(return_val) == 2 and player_num <= 1:
            for i in range(len(return_val)):
                return_val[i] = filter_name(return_val[i])
            return (return_val[player_num])
        else:
            return ('no opponent')
    
    #Doubles
    if s_or_d == 'd':
        #only if position exists
        if len(return_val) == 4 and player_num <= 1:
            for i in range(len(return_val)):
                return_val[i] = filter_name(return_val[i])
            #sort names alphbetically
            ret_list = sorted([return_val[player_num*2],return_val[player_num*2 + 1]])
            ret_str = filter_name(ret_list[0]) + ',' + ret_list[1]
            return (ret_str)
        else:
            return ('no opponent')

# %%
#Create the dataframes for each event
df_MS = df[df['EVENT'] == 'MS'].sort_values(by = 'match_week')
df_WS = df[df['EVENT'] == 'WS'].sort_values(by = 'match_week')
df_MD = df[df['EVENT'] == 'MD'].sort_values(by = 'match_week')
df_WD = df[df['EVENT'] == 'WD'].sort_values(by = 'match_week')
df_XD = df[df['EVENT'] == 'XD'].sort_values(by = 'match_week')

#Split players into winners and losers of a match
df_MS['WINNER'] = df_MS['PLAYERS'].apply(lambda x: split_players(x,0,'s'))
df_MS['LOSER'] = df_MS['PLAYERS'].apply(lambda x: split_players(x,1,'s'))
df_WS['WINNER'] = df_WS['PLAYERS'].apply(lambda x: split_players(x,0,'s'))
df_WS['LOSER'] = df_WS['PLAYERS'].apply(lambda x: split_players(x,1,'s'))
df_MD['WINNER'] = df_MD['PLAYERS'].apply(lambda x: split_players(x,0,'d'))
df_MD['LOSER'] = df_MD['PLAYERS'].apply(lambda x: split_players(x,1,'d'))
df_WD['WINNER'] = df_WD['PLAYERS'].apply(lambda x: split_players(x,0,'d'))
df_WD['LOSER'] = df_WD['PLAYERS'].apply(lambda x: split_players(x,1,'d'))
df_XD['WINNER'] = df_XD['PLAYERS'].apply(lambda x: split_players(x,0,'d'))
df_XD['LOSER'] = df_XD['PLAYERS'].apply(lambda x: split_players(x,1,'d'))

# %%
df_main = df_MS.copy(deep = True)
df_main = df_main.append(df_WS)
df_main = df_main.append(df_WD)
df_main = df_main.append(df_MD)
df_main = df_main.append(df_XD)

# %%
df_main
# Out:
#                                       COUNTRIES EVENT  \
# 9058                       ['[JPN] ', '[CHN] ']    MS
# 9117                       ['[CHN] ', '[CHN] ']    MS
# 9113                       ['[CHN] ', '[CHN] ']    MS
# 9108                       ['[CHN] ', '[JPN] ']    MS
# 9104                       ['[CHN] ', '[CHN] ']    MS
# 9102                       ['[CHN] ', '[CHN] ']    MS
# 9098                       ['[CHN] ', '[THA] ']    MS
# 9085                       ['[CHN] ', '[CHN] ']    MS
# 9084                       ['[CHN] ', '[INA] ']    MS
# 9074                       ['[CHN] ', '[CHN] ']    MS
# 9073                       ['[CHN] ', '[CHN] ']    MS
# 9064                       ['[THA] ', '[JPN] ']    MS
# 9063                       ['[CHN] ', '[CHN] ']    MS
# 9056                       ['[CHN] ', '[JPN] ']    MS
# 9047                       ['[CHN] ', '[THA] ']    MS
# 9046                       ['[CHN] ', '[CHN] ']    MS
# 9036                       ['[JPN] ', '[CHN] ']    MS
# 9035                       ['[CHN] ', '[MAS] ']    MS
# 9034                       ['[CHN] ', '[TTO] ']    MS
# 9033                       ['[CHN] ', '[RSA] ']    MS
# 9023                       ['[CHN] ', '[CHN] ']    MS
# 9022                       ['[JPN] ', '[CHN] ']    MS
# 9021                       ['[CHN] ', '[MAS] ']    MS
# 9020                       ['[CHN] ', '[THA] ']    MS
# 9010                       ['[CHN] ', '[CHI] ']    MS
# 9009                       ['[THA] ', '[CHN] ']    MS
# 9122                       ['[CHN] ', '[CHN] ']    MS
# 9008                       ['[CHN] ', '[CHN] ']    MS
# 9007                       ['[CHN] ', '[CHN] ']    MS
# 14486                      ['[SWE] ', '[SLO] ']    MS
# ...                                         ...   ...
# 3854   ['[RUS] ', '[RUS] ', '[GER] ', '[GER] ']    XD
# 3853   ['[POL] ', '[POL] ', '[DEN] ', '[DEN] ']    XD
# 3852   ['[POL] ', '[POL] ', '[LTU] ', '[LTU] ']    XD
# 3949   ['[POL] ', '[POL] ', '[RUS] ', '[RUS] ']    XD
# 3950   ['[MAS] ', '[MAS] ', '[SUI] ', '[ENG] ']    XD
# 3981   ['[POL] ', '[POL] ', '[UKR] ', '[UKR] ']    XD
# 3952   ['[DEN] ', '[DEN] ', '[GRE] ', '[GRE] ']    XD
# 4516   ['[MRI] ', '[MRI] ', '[MRI] ', '[MRI] ']    XD
# 4513   ['[MDV] ', '[MDV] ', '[MRI] ', '[MRI] ']    XD
# 4512   ['[MRI] ', '[MRI] ', '[MRI] ', '[MRI] ']    XD
# 4511   ['[MDV] ', '[MDV] ', '[MRI] ', '[MRI] ']    XD
# 4510   ['[MRI] ', '[MRI] ', '[COD] ', '[COD] ']    XD
# 4527   ['[MDV] ', '[MDV] ', '[MRI] ', '[MRI] ']    XD
# 4529   ['[MDV] ', '[MDV] ', '[MRI] ', '[MRI] ']    XD
# 4537   ['[MRI] ', '[MRI] ', '[MDV] ', '[MDV] ']    XD
# 4544   ['[MRI] ', '[MRI] ', '[MDV] ', '[MDV] ']    XD
# 3958   ['[POL] ', '[POL] ', '[NOR] ', '[NOR] ']    XD
# 4007   ['[POL] ', '[POL] ', '[DEN] ', '[DEN] ']    XD
# 4000   ['[ENG] ', '[ENG] ', '[POL] ', '[POL] ']    XD
# 3991   ['[POL] ', '[POL] ', '[UKR] ', '[UKR] ']    XD
# 3986   ['[DEN] ', '[DEN] ', '[CZE] ', '[CZE] ']    XD
# 4521   ['[MRI] ', '[MRI] ', '[MRI] ', '[MRI] ']    XD
# 3976   ['[ENG] ', '[ENG] ', '[RUS] ', '[RUS] ']    XD
# 3957   ['[IRL] ', '[IRL] ', '[USA] ', '[USA] ']    XD
# 3956   ['[ENG] ', '[ENG] ', '[CZE] ', '[CZE] ']    XD
# 3955   ['[CZE] ', '[CZE] ', '[NOR] ', '[NOR] ']    XD
# 3954   ['[UKR] ', '[UKR] ', '[ENG] ', '[SCO] ']    XD
# 3953   ['[POL] ', '[POL] ', '[ISL] ', '[ISL] ']    XD
# 3951   ['[POL] ', '[POL] ', '[ISL] ', '[ISL] ']    XD
# 3959   ['[POL] ', '[POL] ', '[NOR] ', '[NOR] ']    XD
#
#                                                  PLAYERS  \
# 9058                  ['Onodera Yusuke', 'Chen Haoyang']
# 9117                  ['Zhao Junpeng [2]', 'Zhu Siyuan']
# 9113                          ['Sun Feixiang', 'Wu Xin']
# 9108              ['Zhao Junpeng [2]', 'Onodera Yusuke']
# 9104                               ['Wu Xin', 'Guo Kai']
# 9102                      ['Sun Feixiang', 'Gu Junfeng']
# 9098             ['Zhu Siyuan', 'Wangcharoen Kantaphon']
# 9085                 ['Zhao Junpeng [2]', 'Haichao Liu']
# 9084                   ['Sun Feixiang', 'Andre Marteen']
# 9074                     ['Zhu Siyuan', 'Hongyang Weng']
# 9073                          ['Gu Junfeng', 'Xin Tang']
# 9064    ['Wangcharoen Kantaphon', 'Hashiru Shimono [4]']
# 9063                            ['Wu Xin', 'Guangzu Lu']
# 9056                  ['Guo Kai', 'Kanta Tsuneyama [1]']
# 9047              ['Chen Haoyang', 'Korakrit Laotrakul']
# 9046                          ['Guo Kai', 'Gao Zhengze']
# 9036                      ['Onodera Yusuke', 'Xin Anqi']
# 9035                        ['Xin Tang', 'Eddrall Atek']
# 9034                ['Zhu Siyuan', 'Nicholas Bonkowsky']
# 9033                ['Gu Junfeng', 'Jacob Maliekal [3]']
# 9023                  ['Zhao Junpeng [2]', 'Junchen An']
# 9022                ['Hashiru Shimono [4]', 'Guo Xinwa']
# 9021                  ['Hongyang Weng', 'Kee Liang Lau']
# 9020               ['Wu Xin', 'Kantawat Leelavechabutr']
# 9010                        ['Haichao Liu', 'Qin Zheng']
# 9009             ['Wangcharoen Kantaphon', 'Yupeng Bai']
# 9122                ['Sun Feixiang', 'Zhao Junpeng [2]']
# 9008                      ['Sun Feixiang', 'Ren Pengbo']
# 9007                       ['Guangzu Lu', 'Ye Binghong']
# 14486                     ['Andy Tsai', 'Andraz Krapez']
# ...                                                  ...
# 3854   ['Mikhail Lavrikov', 'Anastasiia Shapovalova',...
# 3853   ['Aleksander Jablonski', 'Kornelia Marczak', '...
# 3852   ['Dominik Zietek', 'Wiktoria Adamek', 'Lauryna...
# 3949   ['Konrad Ploch', 'Aleksandra Goszczynska', 'Ge...
# 3950   ['Eveshgaran Vasigaran', 'Dharshinie Vasigaran...
# 3981   ['Pawel Smilowski [1]', 'Magdalena Swierczynsk...
# 3952   ['Jesper Toft', 'Natasja P. Anthonisen', 'Petr...
# 4516   ['Khabir Teeluck', 'Ganesha Mungrah', 'Ashneel...
# 4513   ['Sarim Mohamed', 'Moosa Aminath Shahurunaz', ...
# 4512   ['Khabir Teeluck', 'Ganesha Mungrah', 'Ravin A...
# 9009                                          Yupeng Bai
# 9122                                        Zhao Junpeng
# 9008                                          Ren Pengbo
# 9007                                         Ye Binghong
# 14486                                      Andraz Krapez
# ...                                                  ...
# 3854                           Lena Germann,Lukas Junker
# 3853                 Clara Graversen,Sebastian Grønbjerg
# 3852               Laurynas Borusas,Rebeka Alekseviciute
# 3949                Anastasiia Kurdyukova,Georgii Karpov
# 3950                       Manuel Manca,Natalia Mitchell
# 3981                  Dmytro Zavadsky,Vladyslava Lesnaya
# 3952                       Eirini Goygleri,Petros Tentas
# 4516                    Ashneel Dabee,Cindy Soobramanien
# 4513                         Melvin Appiah,Vilina Appiah
# 4512                    Dorothy Rousseau,Ravin Anthi-Iya
# 4511                       Mandira Lubah,Sandesh Gondary
# 4510            Mbuyi Bernice Bokotsha,Mutombo Tshizanga
# 4527                      Ganesha Mungrah,Khabir Teeluck
# 4529                      Kritisha Mungrah,Tejraj Pultoo
# 4537    Aminath Nabeeha Abdul Razzaq,Thoif Ahmed Mohamed
# 4544              Moosa Aminath Shahurunaz,Sarim Mohamed
# 3958                 Jesper Kristensen,Marie Christensen
# 4007                   Jesper Toft,Natasja P. Anthonisen
# 4000              Magdalena Swierczynska,Pawel Smilowski
# 3991                       Anna Mikhalkova,Artem Tkachuk
# 3986                       Filip Budzel,Tereza Švábíková
# 4521                 Abhay Chandra Russom,Sendila Mourat
# 3976             Anastasiia Shapovalova,Mikhail Lavrikov
# 3957   Jacqueline Wendy Myers,Pedro Arturo Garcia-Flores
# 3956                     Bedrich Valenta,Martina Krocová
# 3955                    Carl Christian Mork,Elisa Wiborg
# 3954                       Avinash Gupta,Basia Grodynska
# 3953            Kristofer Darri Finnsson,Thorunn Eylands
# 3951              Daniel Johannesson,Sigridur Arnadottir
# 3959          Fredrik Kristensen,Solvår Flåten Jørgensen
#
# [15575 rows x 18 columns]

# %%
def neg_ind(x):
    if x<0:
        return (1)
    else:
        return (0)
    
df_main['Wind - Losed'] = df_main['Winner Distance'] - df_main['Loser Distance']
df_main['Winner_Closer_ind'] = df_main['Wind - Losed'].apply(lambda x:neg_ind(x))

# %%
len(df_main)
# Out:
# 15575

# %%
print(df_main['Winner Distance'].mean())
df_main['Winner Distance'].plot(kind = 'hist', bins = 50)
# Out:
# 4131.666011420821

# %%
print(df_main['Loser Distance'].mean())
df_main['Loser Distance'].plot(kind = 'hist', bins = 50)
# Out:
# 3412.4411873016356

# %%
df_main['Loser Distance'].std()
# Out:
# 4315.710475227261

# %%
df_main['Winner Distance'].std()
# Out:
# 4638.006588103877

# %% [markdown]
# # Mann - Whitney U test

# %%
from scipy.stats import mannwhitneyu

# %%
data1 = np.array(df_main['Loser Distance'].dropna())
data2 = np.array(df_main['Winner Distance'].dropna())
# compare samples
stat, p = mannwhitneyu(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Statistics=107780893.500, p=0.000
# Different distribution (reject H0)

# %%
#Take out scrubs
no_scrub = df_main.copy(deep = True)
for scrub in tqdm(scrubs):
    no_scrub = no_scrub[no_scrub['PLAYERS'].str.contains(scrub) == False]
# Out:
#  21%|████████████████▉                                                              | 544/2543 [00:13<00:48, 41.50it/s]

# %%
data1 = np.array(no_scrub['Loser Distance'].dropna())
data2 = np.array(no_scrub['Winner Distance'].dropna())
# compare samples
stat, p = mannwhitneyu(data2, data1)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')

# %%
no_scrub['Loser Distance'].mean()

# %%
no_scrub['Winner Distance'].mean()

# %% [markdown]
# # Test for exponential

# %%
from scipy.stats import anderson

# %%
anderson(np.array(df_main['Winner Distance'].dropna()), dist = 'expon')
# Out:
# AndersonResult(statistic=557.3683750053169, critical_values=array([0.922, 1.078, 1.341, 1.606, 1.957]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
from scipy.stats import kstest

# %%
kstest(np.array(df_main['Winner Distance'].dropna()), 'expon')
# Out:
# KstestResult(statistic=0.9996625105647076, pvalue=0.0)

# %% [markdown]
# # Make into normal

# %%
norm_win_dist = list(df_main['Winner Distance'])
temp_list = []
for i in norm_win_dist:
    temp_list.append(i)
    temp_list.append(-i)

temp_df = pd.DataFrame()
temp_df['Winner Distance'] = temp_list

# %%
temp_df['Winner Distance'].dropna().plot(kind = 'hist', bins = 50)

# %%
# Shapiro-Wilk Test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import shapiro
import numpy as np

# %%
from scipy.stats import shapiro
data = np.array(list(temp_df['Winner Distance'].dropna()))
# normality test
stat, p = shapiro(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# c:\users\andrew.zhuang\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\morestats.py:1310: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Statistics=0.938, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
from scipy.stats import normaltest
data = np.array(list(temp_df['Winner Distance'].dropna()))
# normality test
stat, p = normaltest(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=793.247, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
from scipy.stats import anderson
data = np.array(list(temp_df['Winner Distance'].dropna()))
# normality test
result = anderson(data)
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
	sl, cv = result.significance_level[i], result.critical_values[i]
	if result.statistic < result.critical_values[i]:
		print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
	else:
		print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# Statistic: 934.025
# 15.000: 0.576, data does not look normal (reject H0)
# 10.000: 0.656, data does not look normal (reject H0)
# 5.000: 0.787, data does not look normal (reject H0)
# 2.500: 0.918, data does not look normal (reject H0)
# 1.000: 1.092, data does not look normal (reject H0)

# %%
# Out:
# 31148

# %%
df_main['Wind - Losed'].plot(kind = 'hist', bins = 30)

# %%
df_main['Wind - Losed'].mean()
# Out:
# 720.1144732818311

# %%
df_main['Wind - Losed'].std()
# Out:
# 5259.549192106415

# %%
distance_travelled = list(df_main['Winner Distance']) + list(df_main['Loser Distance'])

# %%
df_temp = pd.DataFrame()
df_temp['a'] = distance_travelled
print(df_temp['a'].mean())
print(df_temp['a'].std())
df_temp['a'].plot(kind = 'hist')
# Out:
# 3772.1344344944746
# 4494.133524444806

# %%
df_main['Winner_Closer_ind'].mean()
# Out:
# 0.3798394863563403

# %%
team_list = []
win_distance = []
lose_distance = []
win_pct = []
matches_played = []
for team in tqdm(df_main['WINNER'].unique()):
    team_list.append(team)
    win_distance.append(df_main[df_main['WINNER'] == team]['Winner Distance'].mean())
    lose_distance.append(df_main[df_main['LOSER'] == team]['Loser Distance'].mean())
    matches_played.append(len(df_main[df_main['WINNER'] == team]) + len(df_main[df_main['LOSER'] == team]))
    if len(df_main[df_main['LOSER'] == team]) != 0:
        win_pct.append(len(df_main[df_main['WINNER'] == team])/(len(df_main[df_main['LOSER'] == team]) + len(df_main[df_main['WINNER'] == team])))
    else:
        win_pct.append(1)
        
df_dist = pd.DataFrame()
df_dist['Team'] = team_list
df_dist['Win Dist'] = win_distance
df_dist['Lose Dist'] = lose_distance    
df_dist['Win Pct'] = win_pct
df_dist['Matches Played'] = matches_played
df_dist['Win dist - Lose dist'] = df_dist['Win Dist'] - df_dist['Lose Dist']
df_dist['Win dist - Lose dist'].plot(kind = 'hist', bins = 50)
df_dist['Win dist - Lose dist'].mean()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3815/3815 [00:55<00:00, 68.32it/s]
# 31.908621638267594

# %%
df_dist
# Out:
#                                                   Team     Win Dist  \
# 0                                       Onodera Yusuke  3448.066472
# 1                                         Zhao Junpeng  4386.773114
# 2                                         Sun Feixiang  3031.946732
# 3                                               Wu Xin   835.149641
# 4                                           Zhu Siyuan  1074.015469
# 5                                           Gu Junfeng  1153.637412
# 6                                Wangcharoen Kantaphon  1256.734299
# 7                                              Guo Kai   835.149641
# 8                                         Chen Haoyang   835.149641
# 9                                             Xin Tang   835.149641
# 10                                     Hashiru Shimono  4101.526827
# 11                                       Hongyang Weng   864.293712
# 12                                         Haichao Liu   835.149641
# 13                                          Guangzu Lu   835.149641
# 14                                           Andy Tsai  2665.531313
# 15                                          Erik Meijs  2698.772843
# 16                                   Alexander Roovers  1303.564214
# 17                                           Raul Must  1274.743807
# 18                                          Eetu Heino  1479.615060
# 19                                       Subhankar Dey  7358.714103
# 20                                   Toma Junior Popov  2201.510523
# 21                                         Birger Abts  2424.554631
# 22                                        Hermansyah .  8710.596898
# 23                                      Douglas Lidman  1952.692240
# 24                                       Jacob Nilsson  1759.009956
# 25                                       Arto Lahtinen   503.713498
# 26                                  Karolis Eimutaitis   426.153584
# 27                                     Mattias Wigardt  1011.680349
# 28                                         Joel Koenig  2274.013702
# 29                                      Rok Jercinovic  1776.227939
# ...                                                ...          ...
# 3785                 Jesper Toft,Natasja P. Anthonisen  1533.237094
# 3786               Clara Graversen,Sebastian Grønbjerg  1525.172153
# 3787                    Sharone Bauer,William Villeger  2596.375691
# 3788           Anastasiia Shapovalova,Mikhail Lavrikov  8107.678829
# 3789                           Abigail Holden,Adam Lam  2838.209599
# 3790                  Jule Petrikowski,Malte Laibacher  1598.035367
# 3791                    Agnieszka Foryta,Maciej Ociepa   641.951638
# 3792              Anastasiia Kurdyukova,Georgii Karpov  8116.122453
# 3793                Joke De Langhe,Jona Van Nieuwkerke  2219.194616
# 3786  1545.334506  0.750000               4         -2.016235e+01
# 3787  1583.642939  0.600000               5          1.012733e+03
# 3788  7880.804118  0.571429               7          2.268747e+02
# 3789  2838.209599  0.500000               2          0.000000e+00
# 3790  1598.035367  0.800000               5          0.000000e+00
# 3791   674.066282  0.750000               4         -3.211464e+01
# 3792  8112.745003  0.750000               8          3.377449e+00
# 3793  2219.194616  0.500000               2          0.000000e+00
# 3794   674.066282  0.500000               2          0.000000e+00
# 3795          NaN  1.000000               3                   NaN
# 3796          NaN  1.000000               1                   NaN
# 3797  2596.375691  0.500000               2          0.000000e+00
# 3798   451.886014  0.666667               3          8.508998e+03
# 3799  2596.375691  0.500000               2          0.000000e+00
# 3800          NaN  1.000000               1                   NaN
# 3801  1011.328117  0.666667               3          6.101894e+01
# 3802  2596.375691  0.500000               2          0.000000e+00
# 3803   479.932977  0.666667               3          7.622680e+03
# 3804  1692.800520  0.250000               4         -1.273157e+03
# 3805  8112.745003  0.500000               4         -1.013235e+01
# 3806          NaN  1.000000               3                   NaN
# 3807          NaN  1.000000               1                   NaN
# 3808  7841.031370  0.250000               4          2.615813e+02
# 3809  2075.281907  0.750000               4          0.000000e+00
# 3810  2928.655816  0.333333               3         -9.596374e+01
# 3811   433.706217  0.250000               4          1.440161e+02
# 3812    11.015700  0.666667               3          0.000000e+00
# 3813  2075.281907  0.666667               3          0.000000e+00
# 3814    11.015700  0.500000               2          0.000000e+00
#
# [3815 rows x 6 columns]

# %%
print (df_dist['Win Dist'].mean())
df_dist['Win Dist'].plot(kind = 'hist', bins = 40)
# Out:
# 3260.086164777515

# %%
print (df_dist['Lose Dist'].mean())
df_dist['Lose Dist'].plot(kind = 'hist', bins = 40)
# Out:
# 3236.0342050974627

# %%
data1 = np.array(df_dist['Lose Dist'].dropna())
data2 = np.array(df_dist['Win Dist'].dropna())
# compare samples
stat, p = mannwhitneyu(data2, data1)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Statistics=6779256.500, p=0.037
# Different distribution (reject H0)

# %%
temp = df_dist[df_dist['Matches Played'] > 6]

data1 = np.array(temp['Lose Dist'].dropna())
data2 = np.array(temp['Win Dist'].dropna())
# compare samples
stat, p = mannwhitneyu(data2, data1)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Statistics=777979.000, p=0.062
# Same distribution (fail to reject H0)

# %%
temp = df_dist[df_dist['Matches Played'] <= 6]
scrubs = list(temp['Team'])

# %%
for i in [3,6,9,12,15,18,21,24]:
#     temp = df_dist[df_dist['Matches Played'] < i]
    temp = df_dist[df_dist['Matches Played'] > i-3]
    print((temp['Win dist - Lose dist'].mean(),temp['Win dist - Lose dist'].std()),str(len(temp)))
# Out:
# (31.908621638267594, 1714.7234747369462) 3815
# (6.186857282456793, 1841.6137054318237) 2189
# (-6.278479130475811, 1919.6170831293464) 1272
# (-8.725454472339573, 1850.3369336586281) 849
# (-1.6517531334515447, 1798.5999619544189) 641
# (35.68844626012973, 1740.2416462973663) 475
# (32.835732412424555, 1652.3374810846612) 351
# (-13.939669930715676, 1671.5475166954304) 252

# %%
df_dist['Win dist - Lose dist'].plot(kind = 'hist', bins = 50)

# %% [markdown]
# It appears as it there is no clear trend that distance travelled is affecting the performance of players. There could be several reasons: Balance of pressure, people travel far for easier tournaments...

# %% [markdown]
# ## Convert Country to CD

# %%
df_countries = pd.read_csv('country_list.csv', encoding='Latin-1')

def strip_country(x):
    c = x.split(',')[1].strip(' ')
    temp_df = df_countries[df_countries['Country or Area Name'] == c].sort_index(ascending = False)
    if temp_df.empty:
        print (c)
    else:
        code = list(temp_df['ISO ALPHA-3 Code'])[0]
        return (code)
    
df_main['match_location_cd'] = df_main['match_location'].apply(lambda x: strip_country(x))

# %%
def home_court(x,w_or_l):
    
    if w_or_l == 'w':
        if x['match_location_cd'] == x['Winning Country']:
            return (1)
        else:
            return (0)
    elif w_or_l == 'l':
        if x['match_location_cd'] == x['Losing Country']:
            return (1)
        else:
            return (0)

df_main['Winner Home'] = df_main.apply(lambda x: home_court(x,'w'), axis = 1)
df_main['Loser Home'] = df_main.apply(lambda x: home_court(x,'l'), axis = 1)

# %%
df_main.head()
# Out:
#                  COUNTRIES EVENT                                 PLAYERS  \
# 9058  ['[JPN] ', '[CHN] ']    MS      ['Onodera Yusuke', 'Chen Haoyang']
# 9117  ['[CHN] ', '[CHN] ']    MS      ['Zhao Junpeng [2]', 'Zhu Siyuan']
# 9113  ['[CHN] ', '[CHN] ']    MS              ['Sun Feixiang', 'Wu Xin']
# 9108  ['[CHN] ', '[JPN] ']    MS  ['Zhao Junpeng [2]', 'Onodera Yusuke']
# 9104  ['[CHN] ', '[CHN] ']    MS                   ['Wu Xin', 'Guo Kai']
#
#                                         SCORES match_location  match_week  \
# 9058                 ['11-5', '13-11', '11-6']  Hainan, China    20170110
# 9117  ['11-7', '6-11', '11-7', '6-11', '11-5']  Hainan, China    20170110
# 9113                  ['11-7', '11-6', '11-7']  Hainan, China    20170110
# 9108                 ['11-5', '13-12', '11-3']  Hainan, China    20170110
# 9104                 ['11-1', '11-3', '13-11']  Hainan, China    20170110
#
#      Winning Country Losing Country  Winning Country Coord_x  \
# 9058             JPN            CHN               139.271495
# 9117             CHN            CHN               103.930027
# 9113             CHN            CHN               103.930027
# 9108             CHN            JPN               103.930027
# 9104             CHN            CHN               103.930027
#
#       Winning Country Coord_y     ...      match_location Coord_y  \
# 9058                36.655227     ...                        19.2
# 9117                36.567348     ...                        19.2
# 9113                36.567348     ...                        19.2
# 9108                36.567348     ...                        19.2
# 9104                36.567348     ...                        19.2
#
#       Winner Distance  Loser Distance          WINNER           LOSER  \
# 9058      3448.066472      835.149641  Onodera Yusuke    Chen Haoyang
# 9117       835.149641      835.149641    Zhao Junpeng      Zhu Siyuan
# 9113       835.149641      835.149641    Sun Feixiang          Wu Xin
# 9108       835.149641     3448.066472    Zhao Junpeng  Onodera Yusuke
# 9104       835.149641      835.149641          Wu Xin         Guo Kai
#
#       Wind - Losed Winner_Closer_ind match_location_cd  Winner Home  \
# 9058   2612.916831                 0               CHN            0
# 9117      0.000000                 0               CHN            1
# 9113      0.000000                 0               CHN            1
# 9108  -2612.916831                 1               CHN            1
# 9104      0.000000                 0               CHN            1
#
#       Loser Home
# 9058           1
# 9117           1
# 9113           1
# 9108           0
# 9104           1
#
# [5 rows x 23 columns]

# %% [markdown]
# # Home court advantage

# %% [markdown]
# It may be the case that distance doesn't matter - it's an unfamiliar resting spot plus home crowd that makes a difference

# %%
df_hc = df_main[['PLAYERS','match_location','WINNER','LOSER','Winner Home','Loser Home']]

# %%
player_name = []
home_rounds = []
away_rounds = []

for pn in tqdm(df_hc['WINNER'].unique()):
    player_name.append(pn)
    temp = df_hc[df_hc['WINNER'].str.contains(pn)]
    temp['rounds'] = [1]*len(temp)
    temp = temp[['match_location','Winner Home','rounds']].groupby('match_location').sum().reset_index()

    home_rounds.append(temp[temp['Winner Home'] >= 1]['rounds'].mean())
    away_rounds.append(temp[temp['Winner Home'] == 0]['rounds'].mean())

df_homecourt = pd.DataFrame()
df_homecourt['Player/Team'] = player_name
df_homecourt['Home Rounds'] = home_rounds
df_homecourt['Away Rounds'] = away_rounds
df_homecourt['diff'] = df_homecourt['Home Rounds'] - df_homecourt['Away Rounds']
# Out:
#   0%|                                                                                         | 0/3815 [00:00<?, ?it/s]c:\users\andrew.zhuang\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
#  35%|███████████████████████████▍                                                  | 1344/3815 [01:19<02:26, 16.84it/s]c:\users\andrew.zhuang\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# 100%|██████████████████████████████████████████████████████████████████████████████| 3815/3815 [03:39<00:00, 17.39it/s]

# %%
df_homecourt['diff'].plot(kind = 'hist')

# %%
df_homecourt['diff'].mean()
# Out:
# 0.3415999733226624

# %%
df_homecourt.dropna()['Away Rounds'].mean()
# Out:
# 2.251653994931306

# %%
df_homecourt.dropna()['Home Rounds'].mean()
# Out:
# 2.5932539682539684

# %%
df_homecourt['Away Rounds'].plot(kind = 'hist')

# %%
df_homecourt['Home Rounds'].plot(kind = 'hist')

# %%
df_homecourt['Away Rounds'].mean()
# Out:
# 2.0657920457216234

# %%
data1 = np.array(df_homecourt['Home Rounds'].dropna())
data2 = np.array(df_homecourt['Away Rounds'].dropna())
# compare samples
stat, p = mannwhitneyu(data2, data1)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Statistics=2272092.000, p=0.000
# Different distribution (reject H0)

# %%
data1 = np.array(df_homecourt['Home Rounds'])
data2 = np.array(df_homecourt['Away Rounds'])
# compare samples
stat, p = mannwhitneyu(data2, data1)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Statistics=5588598.000, p=0.000
# Different distribution (reject H0)

# %%
### EXTRACT COUNTRY IN match location and match it with it's code, and then identify home.

## Groupby Match locations to see rounds (not code)

# See how many rounds the home loctaion has compared to others

# %%
df_homecourt.dropna()['Away Rounds'].mean()
# Out:
# 2.251653994931306

# %%
df_homecourt['diff'].plot(kind = 'hist')
print ('Home Court Mean: ' + str(df_homecourt['diff'].mean()))
print ('Home Court Standard Deviation: ' + str(df_homecourt['diff'].std()))
# Out:
# Home Court Mean: 0.3415999733226624
# Home Court Standard Deviation: 2.0532297071981733

# %%
df_homecourt['diff'].mean()
# Out:
# 0.3415999733226624
