# %%
import pandas as pd
from tqdm import tqdm
import re

# %%
# Join the files
df = pd.DataFrame()
import glob


for filename in glob.glob('/Users/andrewzhuang/Desktop/Badminton Data/jnotebooks/2018 Tournaments/*.csv'):
    df_temp = pd.read_csv(filename)
    del df_temp['Unnamed: 0']
    df = df.append(df_temp)

for filename in glob.glob('/Users/andrewzhuang/Desktop/Badminton Data/jnotebooks/2017 Tournaments/*.csv'):
    df_temp = pd.read_csv(filename)
    del df_temp['Unnamed: 0']
    df = df.append(df_temp)

# %%
def filter_name(string):
    del_chars = ['[',']','1','2','3','4','5','6','7','8','9','0']
    return_string = string
    for char in string:
        if char in del_chars:
            return_string = return_string.replace(char,'')
    
    return_string = return_string.strip()
    return (return_string)

# %%
#Take in line, player team you want to extract and singles or doubles
def split_players(x,player_num,s_or_d):
    #Need to filter out using regex
    return_val = re.findall("'(.*?)'",x)
    
    #Singles
    if s_or_d == 's':
        #only if there are two opponents
        if len(return_val) == 2 and player_num <= 1:
            for i in range(len(return_val)):
                return_val[i] = filter_name(return_val[i])
            return (return_val[player_num])
        else:
            return ('no opponent')
    
    #Doubles
    if s_or_d == 'd':
        #only if position exists
        if len(return_val) == 4 and player_num <= 1:
            for i in range(len(return_val)):
                return_val[i] = filter_name(return_val[i])
            #sort names alphbetically
            ret_list = sorted([return_val[player_num*2],return_val[player_num*2 + 1]])
            ret_str = filter_name(ret_list[0]) + ',' + ret_list[1]
            return (ret_str)
        else:
            return ('no opponent')

# %%
#This function will create a dictionary with trueskill rankings for each player
def create_event_dict_PM_and_TP(df):
    temp_dict = {}
    temp_set = set()
    for player in df['WINNER'].values:
        temp_set.add(player)
    for player in df['LOSER'].values:
        temp_set.add(player)
    
    for player in temp_set:
        temp_dict[player] = 0
    return (temp_dict)

def create_event_dict_WL(df):
    temp_dict = {}
    temp_set = set()
    for player in df['WINNER'].values:
        temp_set.add(player)
    for player in df['LOSER'].values:
        temp_set.add(player)
    
    for player in temp_set:
        temp_dict[player] = [0,0]
    return (temp_dict)

# %%
def update_win_loss(df,event_dict):
    for person in df['WINNER']:
        event_dict[person][0] += 1
    for person in df['LOSER']:
        event_dict[person][1] += 1
    return (event_dict)

def update_total_points(df,event_dict):
    for i in range(len(df)):
        event_dict[df.iloc[i]['WINNER']] += df.iloc[i]['WINNER POINTS']
        event_dict[df.iloc[i]['LOSER']] += df.iloc[i]['LOSER POINTS']
    return (event_dict)

def update_total_PLUSMINUS(df,event_dict):
    for i in range(len(df)):
        event_dict[df.iloc[i]['WINNER']] += df.iloc[i]['WINNER +-']
        event_dict[df.iloc[i]['LOSER']] += df.iloc[i]['LOSER +-']
    return (event_dict)

# %%
#stat num:
#         1 - winner total points
#         2 - loser total points
#         3 - winner set plus minus
#         4 - loser set plus minus

def player_point_split(x,stat_num):
    del_chars = ['[',']',"'",' ']
    return_string = x
    for char in x:
        if char in del_chars:
            return_string = return_string.replace(char,'')
    
    sets = return_string.split(',')
    
    winner_total_points = 0
    loser_total_points = 0
    
    winner_set_pm = 0
    loser_set_pm = 0

    for game in sets:
        if len(game) > 0:
            scores = game.split('-')
            winner_set_pm += int(scores[0]) - int(scores[1])
            loser_set_pm += int(scores[1]) - int(scores[0])
            winner_total_points += int(scores[0])
            loser_total_points += int(scores[1])
            
    if stat_num == 1:
        return (winner_total_points)
    elif stat_num == 2:
        return (loser_total_points)
    elif stat_num == 3:
        return (winner_set_pm)
    elif stat_num == 4:
        return (loser_set_pm)

df['WINNER POINTS'] = df['SCORES'].apply(lambda x: player_point_split(x,1))
df['LOSER POINTS'] = df['SCORES'].apply(lambda x: player_point_split(x,2))
df['WINNER +-'] = df['SCORES'].apply(lambda x: player_point_split(x,3))
df['LOSER +-'] = df['SCORES'].apply(lambda x: player_point_split(x,4))

# %%
MS_dict = create_event_dict_PM_and_TP(df_MS)

# %%
update_total_PLUSMINUS(df_MS,MS_dict)
# Out:
# {'Shubham Prajapati': 45,
#  'Femi Bioku': 14,
#  'Joo Ven Soong': 841,
#  'Niels VEENSTRA': 54,
#  'Soo Teck Zhi': 24,
#  'Gilmar Jones': 12,
#  'Manuel Del Rosario Pargas': -46,
#  'Wilmer Daniel Brea Nuñez': 167,
#  'Zvonimir Durkinjak': 663,
#  'Danny Chen': 70,
#  'Wei Chi Liu': 54,
#  'Shabahang Asgari': -5,
#  'Ahmad Ali': -12,
#  'Adam Mubiru': 53,
#  'Bongani Von Bodenstein': 95,
#  'Adam Mendrek': 916,
#  'Thanh Long Truong': 42,
#  'Manuel Mejia': -10,
#  'Chun-Wei Chen': 470,
#  'Rezha Akbar Raja Husain': 48,
#  'Bao Duc Duong': 42,
#  'Mohamed Mahmoud Djitli': 83,
#  'Izak Batalha': 30,
#  'Koki Watanabe': 1373,
#  'Adel Hamek': 199,
#  'Javier Macagno': 77,
#  'Victor Alves': -12,
#  'Idrisse Issofo Mossagy': -2,
#  'Alexander Butovetstkiy': 25,
#  'Yonathan Ramlie': 165,
#  'Enrique Iglesia Cordero': 20,
#  'Luke Pearce': 198,
#  'Jose Guevara /': 198,
#  'Ondřej Král': 572,
#  'Kasper Lehikoinen': 202,
#  'Hemanth M.Gowda': 335,
#  'Humblers Heymard': 273,
#  'Khaitmurat Kulmatov': 6,
#  'Kaninpong Yokard': 146,
#  'Soong Joo Ven': 216,
#  'Murat Sen': 229,
#  'Soravis Pijitpalakad': 2,
#  'Mateo Maira': 10,
#  'Fernando Sanhueza': 12,
#  'Aman Kumar': 79,
#  'Elias Bracke': 172,
#  'Peder Søvndal': 112,
#  'Artur Silva Pomoceno': 888,
#  'Farzin Khanjani': 218,
#  'Mattias Wigardt': 83,
#  'Son Wan Ho': 1209,
#  'Rajiv Ouseph': 838,
#  'Godwin Olofua': 182,
#  'Tarepa Bourgery': 14,
#  'Facundo Ayala': 47,
#  'Phillips Jap': 128,
#  'Yuki Liu': 32,
#  'Juan Ignacio Segui': 60,
#  'Vincent Medina': 143,
#  'Ko Joon Hyung': 45,
#  'Subhankar Dey': 1076,
#  'Mohamad Pairavand': 98,
#  'Nicolas Macias': 214,
#  'Haruki Fukuda': 133,
#  'Heo Kwang Hee': 65,
#  'Thomas Rouxel': 685,
#  'Lin Bing-Wei': 29,
#  'Kalonde Charles': -22,
#  'Leon Jang': -10,
#  'Artem Serpionov': -19,
#  'Kettiya Keoxay': 35,
#  'Clement Krobakpo': 589,
#  'Jiann Shiarng Chiang': 8,
#  'Daisuke Omoto': 47,
#  'Datu Mohd Shah Eizlan Sardik': 182,
#  'Christopher Steeghs': -2,
#  'Chengming Ren': 29,
#  'Arturo Hernandez': 130,
#  'Saul Solis': -24,
#  'Ayila Gwambeh': 4,
#  'Mohamed Amine Guelmaoui': 46,
#  'Kai Ho Tang': 115,
#  'Truong Thanh Long': 64,
#  'Jing Ping Ng': 67,
#  'Christopher Alexander Martinez Salvador': 839,
#  'Robert Mann': 797,
#  'Joel Douse': 145,
#  'Yupeng Bai': 244,
#  'Mohammed Almashaekhi': -1,
#  'Sajan Krishna Tamrakar': -6,
#  'Dimitar Yanakiev': 166,
#  'Liu Wei Chi': 132,
#  'Cheng Phorrom': 57,
#  'Naoki Yamazawa': 404,
#  'Brian Yang': 504,
#  'Li Xiang': 14,
#  'Haidar M. Besha': 50,
#  'Akito Homma': 10,
#  'Mitchel Wongsodikromo': 55,
#  'Remi Rossi': 413,
#  'Walid Belaidene': 6,
#  'Christopher Paul': 477,
#  'Noppanai Singrueang': 280,
#  'Stanislav Pukhov': 250,
#  'Hussein Zayan Shaheed': 28,
#  'Sergey Sirant': 654,
#  'Kim Min Ki': 222,
#  'Nikolai Baranov': -2,
#  'Blagovest Kisyov': 29,
#  'Rodolfo Ramirez': 90,
#  'Karono Suwarno': 273,
#  'Kevin Arokia Walter': 21,
#  'Peter Correl': 26,
#  'Abdul Bari Ansari': 32,
#  'Abhishek Kulkarni': 47,
#  'Christoffer Elbrønd': 53,
#  'Sebastian Martinez Cardoso': 48,
#  'Giap Chin Goh': 1018,
#  'Daniel Steyn': -10,
#  'Arturo Joel Angeles Garcia': 10,
#  'Armin Zakizadeh': 66,
#  'Kanta Tsuneyama': 1189,
#  'Moustafa Bumpenje': 0,
#  'Davies Senono': 115,
#  'Phillipe Charron': 52,
#  'Jarred Elliot': 62,
#  'Hin Shun Wong': 218,
#  'Mohsen Masoumitabarzanjani': 60,
#  'Anton Ivanov': 30,
#  'Vinicius Oliveira Silva': -8,
#  'Gabriel Urteaga Hammond': -6,
#  'Orkhan Galandarov': -6,
#  'Ajay Jayaram': 605,
#  'Rudolf Dellenbach': 505,
#  'Miguel Rocha': 8,
#  'Kemar Valentine': 24,
#  'Amit Sharma': -10,
#  'Tony Wang': -8,
#  'Kirk Francis': 16,
#  'Edwin Ekiring': 163,
#  'Purevsuren Enkhmandakh': -22,
#  'Takuma Ueda': 514,
#  'Mitthren Raj Veerappen': -24,
#  'Adi Pratama': 141,
#  'Heinoa Deane': -22,
#  'Nicardo Reid': 61,
#  'Lucas Claerbout': 1022,
#  'Alfonso Garcia-Rosell': -2,
#  'Francielton Farias': 53,
#  'Anthony Murillo': -10,
#  'Lin Chun-Yi': 455,
#  'Pawel Pradzinski': 123,
#  'Diego Castillo': -12,
#  'Chang En Chia': 230,
#  'Jun Yan Ng': 213,
#  'Tan Muhammad Elaf Wei': -4,
#  'Bryan Rodrigo Roque Caycho': 32,
#  'Lau Yu Ming, Adam': 24,
#  'Wesley Caulkett': 175,
#  'Jean Bernard BONGOUT': 24,
#  'Sungwook Hyun': 44,
#  'Yunusa Momoh': 30,
#  'Jack Jiang': 24,
#  'Mikhail Ghelashvili': 70,
#  'Supakit Jandara': 12,
#  'Peter Roenn Stensaeth': 95,
#  'Thammasin Sitthikom': 705,
#  'Anatoliy Yartsev': 468,
#  'Joao Marcos Moreira': 74,
#  'Francisco Brandao': 25,
#  'Muhammad Lukman Hakim Mohd Ibrahim': 167,
#  'Mestapaha Kessari': 66,
#  'Lukas Osele': 181,
#  'Cristian Savin': 403,
#  'Kuo Ching-Hung': 136,
#  'Mehran Shahbazi': 221,
#  'Kim Dong Wook': 6,
#  'Ramadhani Zulkifli': 28,
#  'Sandeep Perumalla': 10,
#  'Rauhiri Goguenheim': -12,
#  'Jack Wang': 88,
#  'Sony Dwi Kuncoro': 542,
#  'Bodhit Joshi': 524,
#  'Parham Khanzadeh': -5,
#  'Aidan Karati': 103,
#  'Eetu Heino': 1078,
#  'Dewantoro Pandu': 209,
#  'Khabir TEELUCK': 26,
#  'Mustaopha Muhammed': 28,
#  'Kentaro Hoshino': 147,
#  'Hongyang Weng': 53,
#  'SAI WUU PHET @ Sai Lin Tun Aung': 133,
#  'Kunlavut Vitidsarn': 755,
#  'Sai Praneeth B.': 1369,
#  'Darel SOPHIE': 50,
#  'Morne De Beer': 29,
#  'Woo Seung Hoon': 85,
#  'Yang Chih Hsun': 20,
#  'Lee Chia Hao': 169,
#  'David Bjarni Bjornsson': 10,
#  'Victor Odra Munga': 33,
#  'Yong Sheng Lin': 20,
#  'Amir Khamidulin': 39,
#  'Christopher Skrzeba': 18,
#  'Kai Schaefer': 571,
#  'Minoru Koga': 200,
#  'Filip Suwanphingkha': 51,
#  'Patrick Hii': 20,
#  'Artyom Savatyugin': 188,
#  'Xiaodong Sheng': 390,
#  'Leodannis Martinez Palacio': 328,
#  'Cristobal Conejero': 48,
#  'Vega Vio Nirwanda': 1152,
#  'Tommy Sugiarto': 1376,
#  'Raul Blondet Martinez': -16,
#  'Yu-Hua Lai': 36,
#  'Phone Pyae Naing': 59,
#  'Edward Lau': 138,
#  'Kevin Lee': 12,
#  'Mateus Carrijo Cutti': 263,
#  'Amir Ghasemi': 44,
#  'Mohamed Abdelaziz Ouchefoun': 143,
#  'Iztok Utrosa': 87,
#  'Felipe Roberto Mendes Ribeiro': 137,
#  'Chen Long': 1133,
#  'Enis Sesalan': 251,
#  'Dillan Kyle Schaap': -8,
#  'Bruno Barrueto Deza': 307,
#  'Joshua Eipe': 156,
#  'Irfan Ali Bhadusha Abdul Vahab': 63,
#  'Habeeb Temitope Bello': 314,
#  'Sitthikom Thammasin': 304,
#  'Alfred Wong': 0,
#  'Mohammed Hasan': -21,
#  'Chu Han Chou': 125,
#  'Kodai Naraoka': 818,
#  'Elias Nicolaou': 8,
#  'Sabuhi Huseynov': 38,
#  'Wan Mohd Hidayat Wan Hassan': 20,
#  'Jack Boyle': 16,
#  'Chuang Jin Lei': 28,
#  'Mihkel Laanes': 89,
#  'Jamal Jared Ronaldo Thijssen': 14,
#  'Muhammad Sufiyuddin Mohamed Shafei': 144,
#  'Roberto Carlos Herrera Vazquez': 4,
#  'Jang Hyun Seok': 55,
#  'Jan Frohlich': 255,
#  'Yifan Zhang': 18,
#  'Luís Enrique Peñalver': 904,
#  'Muhammad Muqeet Tahir': 83,
#  'Marc Zwiebler': 425,
#  'Yazgan Calisir': 8,
#  'Siril Verma': 733,
#  'Burty James Molia': 161,
#  'Gilles Allet': 22,
#  'Amrullo Bakhshullaev': 128,
#  'Erfan Sharghipour': 31,
#  'Isaac Senfuka': -18,
#  'Huang Guoxing': 95,
#  'Wee Peng SIM': 83,
#  'Topsy Phiri': 80,
#  'Expedito Emuddu': -12,
#  'Soren Opti': 469,
#  'Raffick Alfonso': -4,
#  'Mark Banda': 8,
#  'Muhammad Syafiq Iqbal Mohd Nadzri': 104,
#  'Yeoh Seng Zoe': 39,
#  'Kim Yong Hyun': 39,
#  'Thomas Rouglios': 4,
#  'Vinson Chiu': 67,
#  'Santiago Otero': 69,
#  'Soobhan AJMEER': 4,
#  'Daniel Nikolov': 348,
#  'Tshimologo Rasta': -4,
#  'Leong Jun Hao': 115,
#  'Enzo Sugiura': 56,
#  'Evan Lee': 44,
#  'Collins Valentine FILIMON': 138,
#  'Huang Da Wei': 80,
#  'Sai Wuu Phet @ Sai Lin Tun Aung': 16,
#  'Eizlan Shah Misfahul Muneer': -8,
#  'Nicholas Bonkowsky': 56,
#  'Raymond Webster': -26,
#  'Kevin Barkman': 183,
#  'Bjorn Seguin': 584,
#  'Romain Frank': 14,
#  'Jhotiswaran KARUPATHEVAN': 115,
#  'Hans-Kristian Vittinghus': 203,
#  'Fred Kirabo': 112,
#  'Yodsakorn Nualnooplong': 103,
#  'Fahmi Aulia Rahman': 16,
#  'Labieb Muhzafar Lakamagi': 148,
#  'Leonardo Isa': 18,
#  'Wei Nan': 947,
#  'Angel Argenis Marinez Ulloa': -1,
#  'Sİnan Zorlu': 96,
#  'Bouksani Abderrahim': 28,
#  'Jahid Alhasanov': 36,
#  'Siddharth Jakhar': 63,
#  'Ali Hosseinkhani': 20,
#  'Tianyi Xie': 12,
#  'Kevin Yao Lin Zou': 66,
#  'Gunzorig Enkhjargal': 0,
#  'Vinicius Alecrim Paula': 43,
#  'Nicolas Lenggenhager': 2,
#  'Shesar Hiren Rhustavito': 1487,
#  'Luis Martinez': 0,
#  'Ronan Ho-Yagues': 18,
#  'Vladimir Shipilenko': -5,
#  'Arintap Das Gupta': 82,
#  'Jatoonah Ashley': -30,
#  'Bagas Kristianto Nugroho': 186,
#  'Ahmed Nibal': 40,
#  'Osleni Guerrero': 1590,
#  'Chee Foong Lim': -42,
#  'Soroush Eskandari Vatannejad': 197,
#  'Koh Jia Wei Joel': 18,
#  'Vannthoun Vath': -12,
#  'Alireza Qasemi': 26,
#  'Tlamelang Kepaletswe': 22,
#  'Felix Burestedt': 346,
#  'Shi Xuan Dominic Soh': 379,
#  'Bence Pytel': 42,
#  'Dean Bencha Wijaya': -12,
#  'Lin Dan': 1109,
#  'Andrey Parakhodin': -14,
#  'Yusuf Ramazan Bay': 112,
#  'Koji Naito': 235,
#  'Tanongsak Saensomboonsuk': 1205,
#  'Hasan Motaghi': 34,
#  'Donnians Oliveira': 97,
#  'Vi Hen Tan': 55,
#  'Gurusaidutt R. M. V.': 347,
#  'Nonpakorn Nantatheero': 20,
#  'Lautaro Vosylius': -22,
#  'Steven Lesourd': -4,
#  'Naim Mohammed': 91,
#  'Chet Vin Wong': 327,
#  'Raouf Lamrani': -8,
#  'Zhe Ming Nigel Yap': 10,
#  'Janson Trinh': 10,
#  'Kaizar Bobby Alexander': 16,
#  'Anders Antonsen': 1249,
#  'Miguel Marinez': 1,
#  'Jose Carlos Suarez Ataury': 22,
#  'Michal Rogalski': 493,
#  'Andi Fadel Muhammad': 343,
#  'Kai Chen Teoh': 220,
#  'Nazareno Ayala': -6,
#  'Vilson Vattanirappel': 85,
#  'Marius Myhre': 169,
#  'Kristofer Darri Finnsson': 32,
#  'R. M. V. Gurusaidutt': 6,
#  'Douglas Lidman': 26,
#  'Gu Junfeng': 58,
#  'Muzafar Lubega': 51,
#  'Khuvituguldur Byambajav': 86,
#  'Chuan-En Hu': 16,
#  'Danilo Peralez': -8,
#  'Dwayne Watson': 22,
#  'Dang Quang Huy': 8,
#  'Timothy Kafunda': 10,
#  'Fabio Caponio': 639,
#  'Hung Chun Chung': 115,
#  'Yang Chih Chieh': 528,
#  'Mega Ciputra': 42,
#  'Zulfadli Zulkiffli': 893,
#  'Shoaib Riaz': 72,
#  'Vladimir Nikulov': -11,
#  'Phanuwat Srimanta': 78,
#  'Srijan Konchada': 135,
#  'Liu Haichao': 332,
#  'Mathias Pedersen': 61,
#  'Minh Bao': -6,
#  'Iskandar Zulkarnain': 828,
#  'Toby Penty': 693,
#  'Masoud Piroozi': 72,
#  'Yun Kyu Lee': 38,
#  'Sachin Dias': 236,
#  'Yulianto Ilham Sri': 270,
#  'Massinissa Temine': 53,
#  'Bradley Pilgrim': -2,
#  'Oscar Lin': 43,
#  'Kalle Koljonen': 1208,
#  'Abdelhalim Atout': 27,
#  'Sebastian De La Torre': -6,
#  'Prakash Vijayanath': 59,
#  'Manula Peires': -14,
#  'Kento Saeki': 58,
#  'Muhammad Ziyad Md Tah': 110,
#  'Koki Yamada': 41,
#  'Manuel Vazquez': 104,
#  'Hu Chuan-En': 220,
#  'Varot Uraiwong': 52,
#  'Mayank Ahuja': 121,
#  'Mohamed Ajfan Rasheed': 70,
#  'Giap Chin GOH': 142,
#  'Dino Delmastro': 152,
#  'Jason FRANCOIS': 34,
#  'Peter Yan': 329,
#  'Seung Jae Seo': 58,
#  'Anton Kaisti': 352,
#  'Pierrick Cajot': 430,
#  'Luka Milic': 23,
#  'Daniel Philip': 16,
#  'Kanishq M': 42,
#  'Jaromir Janacek': 359,
#  'Vladimir Rusin': 46,
#  'Hong Ji Hoon': 95,
#  'Albert Myles': 2,
#  'Daniel Ferrer Cepero': 39,
#  'Kidambi Srikanth': 987,
#  'Rasmus Messerschmidt': 431,
#  'Yu Jiahao': 2,
#  'Qiao Bin': 775,
#  'Tobias Kuenzi': 124,
#  'Armando Gaitan': 81,
#  'Murad Bayramov': -7,
#  'Viktor Axelsen': 671,
#  'Samuel Ho': 109,
#  'Kenta Nishimoto': 863,
#  'Younes Hafouz': -12,
#  'Jacob Musisi': 107,
#  'Denis Grachev': 297,
#  'Manish Gupta': 14,
#  'Angel Herrera Rodríguez': 359,
#  'Emmanuel Yaw Donkor': 502,
#  'Herbert Ebayo': 113,
#  'Daniel Chislov': 196,
#  'Oscar Guo': 439,
#  'Yann Zaccaria': -14,
#  'Buwaneka Goonethilleka': 262,
#  'Shane Wilson': 59,
#  'Mohamed Abderrahime Belarbi': 295,
#  'Thierry BELLEPEAU': 2,
#  'Kiran Raj Maniraj': 14,
#  'Chen Yen Chun': 111,
#  'Chun Chung Hung': 19,
#  'Paulin Nguele Biya': 41,
#  'Ye Binghong': 232,
#  'Zulficar Issufo Mussagy': -6,
#  'Ethan Chen': 24,
#  'Pablo Sanchez': -12,
#  'William Cabrera': 271,
#  'Ruben Castellanos': 175,
#  'Yi Xin Chew': 10,
#  'Jaspar Woon Chai Yu': 62,
#  'Shahzan Shah Misfahul': 148,
#  'Abbas Alpofead': -7,
#  'Hermansyah .': 102,
#  'Georgii Karpov': 267,
#  'Alex Patrick Zolobe': 132,
#  'Otsile Marumo': 66,
#  'Julien Carraggi': 49,
#  'Koceila Mammeri': 8,
#  'Alireza Faghfouri': -3,
#  'Orijit Chaliha': 37,
#  'Bons Vincent': 16,
#  'Gergely Krausz': 943,
#  'Duarte Nuno Anjo': 1217,
#  'Jia Wei Joel Koh': 12,
#  'Dakeil Jonathan Thorpe': 58,
#  'Ahmed Amine Ksikes': 33,
#  'Lucas Mitchell': 48,
#  'Georges Julien PAUL': 112,
#  'June Wei Cheam': 1336,
#  'Timothy Lam': 190,
#  'David Kim': 235,
#  'Awais Zahid': 80,
#  'Alden Lefilson Putra Mainaky': -2,
#  'Matheus Voigt': 85,
#  'Kim Bruun': 986,
#  'Batdavaa Munkhbat': 179,
#  'Calvin Lin': 20,
#  'Lin Chia Hsuan': 960,
#  'Ryan Tong': 53,
#  'Yim Jong Woo': 96,
#  'Chayanin Susasin': 10,
#  'Abhishek Yeligar': 65,
#  'Aryamann Tandon': 378,
#  'Jacob Schueler': 369,
#  'Bilal Elharab': 112,
#  'Matthew Lee': 155,
#  'Jacob Maliekal': 320,
#  'Lu Chen': 55,
#  'Alonso Medel /': 196,
#  'Fabricio Farias': 608,
#  'Gerelsukh Jargalsaikhan': -10,
#  'Rahul Yadav Chittaboina': 760,
#  'Ernesto Velazquez': 118,
#  'Zin Rei Ryan Ng': 453,
#  'Joyireh Avi Manasye': 66,
#  'Yang Shen': 112,
#  'Sayed Imran Meri': -7,
#  'Naohiro Matsukawa': 109,
#  'Hock Lai Lee': 236,
#  'Muhammad Aiman Abd Malek': 10,
#  'Rory Easton': 18,
#  'Alireza Karami': 63,
#  'Thanapat Rungrattanapon': 40,
#  'Sourabh Varma': 178,
#  'Sebastian Contró': 67,
#  'Che Alexander Beckford': 27,
#  'Mario Cuba': -2,
#  'Muhammad Febriansyah': 69,
#  'Sai Charan Koya': 14,
#  'Michael Opoku Baah': 65,
#  'Ahmed Salah': 493,
#  'Prannoy H. S.': 1511,
#  'Lee Chak Wai': 30,
#  'Joshua Jian Min Khong': 26,
#  'Yik Fong Lim': 62,
#  'Siddharath Thakur': 737,
#  'Noval Ramadhan': 78,
#  'Faiz Rozain': 543,
#  'Ben Torrance': 36,
#  'Huzair Asraaf Ali BHUTTOO': 26,
#  'Ivan Rusev': 661,
#  'Rüdiger Gnedt': 75,
#  'Osvert Riveron': 160,
#  'Yacine Allou': 50,
#  'Joel König': 103,
#  'Heng Lin Ngan': 156,
#  'David Peng': 207,
#  'Sattawat Pongnairat': 101,
#  'Andrew Zhuang': 6,
#  'Kingsley Nelson': 12,
#  'Rhys Walker': 20,
#  'Niccolo Tagle': 75,
#  'Zhou Zeqi': 522,
#  'Nicolas Oliva': 64,
#  'Kaustubh RAWAT': 0,
#  'Ahmed NIBAL': 57,
#  'Pachaarapol Nipornram': 107,
#  'Fahmi Mubarok': 153,
#  'Hikaru Minegishi': 0,
#  'Christo Popov': 65,
#  'Mohamad Chaharmali': 7,
#  'Mohamad Charmali': 38,
#  'Artur Niyazov': 167,
#  'Joel Findlay': 62,
#  'Karono Karono': 133,
#  'Paul Kopolo': 14,
#  'Denzel Sweet': -6,
#  'Wolfgang Gnedt': 414,
#  'Israel Wanagalya': 70,
#  'Kazumasa Sakai': 673,
#  'Jesus Arturo Barajas Lopez': 2,
#  'Rano Boago': 46,
#  'Krzysztof Jakowczuk': 191,
#  'Lee Hyun Deok': 28,
#  'Antonio Emanuel Ortiz': 0,
#  'Atli Tomasson': 16,
#  'Quentin Filliettaz': -6,
#  'Kieran Merrilees': 746,
#  'Krishna Adi Nugraha': 1435,
#  'Said Shahabudin Aini': -15,
#  'Lee Cheuk Yiu': 971,
#  'Said Mohammad Kabir Mirzad': -11,
#  'Joel Angus': 6,
#  'Carlos Daniel Albanes Cordon': 74,
#  'Dzmitry Saidakou': 4,
#  'Wei Feng Chong': 1224,
#  'Auston Govender': -22,
#  'Bhaskar Chakraborty': 61,
#  'Mikkel Enghøj': 174,
#  'Zhao Jie Stanley Chiong': 24,
#  'Leo Lee': 12,
#  'Nathan Tang': 288,
#  'Paul-Antoine Dostie-Guindon': 145,
#  'Hannes Gerberich': 67,
#  'Jun Hong Lee': 59,
#  'Azmy Qowimuramadhoni': 123,
#  'Kari Gunnarsson': 188,
#  'Jeppe Bruun': 99,
#  'Fikri Ihsandi Hadmadi': 930,
#  'Muhammad Irfan Saeed Bhatti': 124,
#  'Jimmy, Yu Lun Tay': 114,
#  'Enzi Shafira': 1451,
#  'Daniel Lopes Aguilera': -2,
#  'Daniel Hardiana Octavianus': 16,
#  'Jonathan Bing Tsan Lai': 62,
#  'Jasmanjot Virk': 131,
#  'Kazuteru Kozai': 187,
#  'Ignacio Maceiras': -20,
#  'Ailton Josue Correa Martinez': 20,
#  'Vishal Sawaram': -8,
#  'Wang Yuehang': 546,
#  'Pannawit Thongnuam': 1608,
#  'Chia Hao Lee': 751,
#  'Misha Zilberman': 1659,
#  'Luis Ramon Garrido': 1324,
#  'Huzair Asraaf Ali Bhuttoo': 28,
#  'George Priestman': 32,
#  'Matin Moghimi': 1,
#  'Park Sung Min': 125,
#  'Shaquille Palmer': 37,
#  'Zohaib Khan Khalil': 28,
#  'Chen Chun-Wei': 220,
#  'Tan Chun Seang': 51,
#  'Melvin APPIAH': 33,
#  'Sameer Verma': 1224,
#  'Hardik Makkar': 23,
#  'Huang Yu Kai': 121,
#  'Tumisang Olekantse': 137,
#  'Kervin Ghislain': 197,
#  'Misbun Ramdan Mohmed Misbun': -4,
#  'Kittipong Imnark': 580,
#  'Ranthushka Sasindu': 155,
#  'Peeranut Sangsomporn': 26,
#  'Chin Yong Chian': 145,
#  'Zach Russ': 216,
#  'Jhotiswaran Karupathevan': 132,
#  'Kittithat Cheiklinthes': -8,
#  'Vincent Cheng Wei Phuah': 68,
#  'Erfan Taran': 63,
#  'Ivan Mayega': 18,
#  'Mahbub Thomi Azizan': 158,
#  'Toma Junior Popov': 697,
#  'Ian Senoga': 28,
#  'Amir Jabbari': 53,
#  'Matteo Bellucci': 265,
#  'Francis Joey Wong': -26,
#  'Hwang Jong Soo': 103,
#  'Cameron Coetzer': 74,
#  'Bai Yupeng': 134,
#  'Daniel La Torre Regal': 941,
#  'Jialanai Luang Amath': 115,
#  'Sherzod Zokhidov': 36,
#  'Zezhou Zhong': 4,
#  'Teklu Endale': -4,
#  'Yu Igarashi': 1134,
#  'Philip Illum Klindt': 80,
#  'Niluka Karunaratne': 1128,
#  'Richard Kuhl': 80,
#  'Giovanni Toti': 533,
#  'Uriel Francisco Canjura Artiga': 457,
#  'Ryota Ichii': 10,
#  'Nick Fransman': 205,
#  'Liew Daren': 203,
#  'Hu Yun': 972,
#  'Abhinav Manota': 630,
#  'Patrick Abildgaard': 148,
#  'Mads Christophersen': 391,
#  'Tuguldur Boldbaatar': 20,
#  'Siddharth .': 172,
#  'Alexander Kim': 2,
#  'Damien Howell': 28,
#  'Gustavo Morales': -42,
#  'Saran Nopphakao': 33,
#  'Kyle Golding': 31,
#  'Shae Michael Martin': 4,
#  'Teh Jia Heng Jason': 12,
#  'Marcin Nowak': 78,
#  'Wibowo Setyaldi Putra': 24,
#  'Sarim Mohamed': 21,
#  'Soogun Z': 42,
#  'Pham Cao Cuong': 325,
#  'Joshua Feng': 65,
#  'Mitch, Aubrey Nai Chung Tong': 75,
#  'Jason Mann': -20,
#  'Eric Jr Timmerman': 34,
#  'Oscar Sunekær': 22,
#  'Dionysius Hayom Rumbaka': 547,
#  'Zhu Siyuan': 67,
#  'Cory Fanus': 143,
#  'Pollakorn Jarasjindawong': -6,
#  'Pang Fong Pui': -6,
#  'Chanmara Tep': 55,
#  'Anthony Joe': 575,
#  'Riki Nur Fajar Rohman': -4,
#  'Soh Shi Xuan Dominic': 51,
#  'Jose Guevara': 731,
#  'Dong Hoon Kim': 152,
#  'Diego Subauste Tokumura /': 104,
#  'Tsamorena Kgosidialwa': 2,
#  'Kento Momota': 941,
#  'Reimi Starling Cabrera Rosario': 160,
#  'Ricky Cheng': 164,
#  'Mek Narongrit': 659,
#  'Enejoh Abah': 118,
#  'Ridzwan Rahmat': 79,
#  'Ibrahimo Issufo Mussagy': -8,
#  'Saran Jamsri': 693,
#  'Milan Ludik': 727,
#  'Fong Hau Sim': 55,
#  'Tien Minh Nguyen': 1379,
#  'Jesper Toft': 196,
#  'Timothy Chiu': 438,
#  'Abdul Karim Hidayat': 43,
#  'Rasmus Gemke': 878,
#  'Hsu Jui Ting': 28,
#  'William Ponsonby': 152,
#  'Kwang Hee Heo': 561,
#  'Datu Mohd Saffuan Nizam Sardik': 186,
#  'Ade Resky Dwicahyo': 351,
#  'Adulrach Namkul': 1208,
#  'Ng Ka Long Angus': 1539,
#  'Tian Houwei': 507,
#  'Rosario Maddaloni': 1767,
#  'Milan Dratva': 417,
#  'Alexey Panov': -23,
#  'Carlos Luna': 68,
#  'Stephan Beeharry': 45,
#  'Alexandr Kozyrev': 156,
#  'Anand Pawar': 319,
#  'Christopher Beecher': -4,
#  'Seong Hyun Son': 24,
#  'Imran Wadia': 16,
#  'Lishwan Mudukasan': 97,
#  'Mevan DEWOO': 2,
#  'Amirabbas Mirbagheri': 12,
#  'Amantle Mosweu': 62,
#  'Septian Dwi Maulana': 14,
#  'Daniel S. Farid': 295,
#  'Vanphason Suvannaphengsy': 26,
#  'John Riad': 37,
#  'Muhammad Izzuddin Shamsul Muzli': 315,
#  'Nhat Nguyen': 402,
#  'Tan Jia Wei': 329,
#  'Aaron Chen': -16,
#  'Ali Ahmed El Khateeb': 59,
#  'Muhammad Syafiq A Sanusi': 127,
#  'Yannick Blondin': 50,
#  'Komandani Maytri Sugiarto': 43,
#  'Francisco Rafael Trevino Buenrostro': 24,
#  'Mohammad Reza Bagheri': 19,
#  'Hermansah .': 364,
#  'Jacob Morgon': -12,
#  'Ashwant Gobinathan': 217,
#  'Ousmane Ouedraogo': -50,
#  'Mohamad Alsawas': 31,
#  'Matthew Yee-Grant': 22,
#  'Sarim MOHAMED': 10,
#  'Leo Rossi': 274,
#  'Kandarp Chaubey': 16,
#  'Mikael Westerback': 14,
#  'Kevin Cordon': 1923,
#  'Mukhammad Rizqy Ramadhani': 174,
#  'Kachain Buarung': 136,
#  'Xaysomphone Vongpachith': 24,
#  'Balraj Kajla': 78,
#  'Tejraj Pultoo': 43,
#  'Wandy Luis Roman Gonzalez': 74,
#  'Aljallad Ahmad': 653,
#  'Liang Hua Chun': 67,
#  'Oscar Bansal': 83,
#  'Stamatis Tsigirdakis': 12,
#  'Kalombo Mulenga': 309,
#  'Mateo Pinto': -20,
#  'Ben Perkinson': 6,
#  'Mathias Thyrri': 41,
#  'Mohammed Al-Ibadi': -25,
#  'Parupalli Kashyap': 881,
#  'Alireza Kazemi': 26,
#  'Daniel Sam': 110,
#  'Kayode Samuel Oyeniran': 18,
#  'Rizky Kurniawan': 50,
#  'Koo Takahashi': 32,
#  'Muhammad Rehan Diaz': 143,
#  'Mehdi Ansari': -7,
#  'Thabani Mathe': 44,
#  'Pavel Kotsarenko': 23,
#  'Olonbayar Enkhbat': 10,
#  'Brian Kasirye': 238,
#  'Leon Seiwald': 345,
#  'Ahmad Balarabe Umar': 2,
#  'Auditya Alpha Hidayat': 119,
#  'Hsu Jen Hao': 1654,
#  'Taiki Kato': 59,
#  'Rizky Doka Putra': 31,
#  'Matej Hlinican': 396,
#  'Julius Mbewe': 6,
#  'Adam Twardzik': -2,
#  'Quentin Bernaix': 95,
#  'Ricky Liuzhou': 212,
#  'Evert Sukamta': 99,
#  'Mariano Novoa': 57,
#  'Andre Marteen': 1103,
#  'Matthew Michel': -4,
#  'Ali Bastani': -13,
#  'Siddharth Pratap Singh': 563,
#  'Perekisi Tshepo': -18,
#  'Bastian Lizama': -2,
#  'Zulhelmi Zulkiffli': 452,
#  'Youssef Hafouz': -38,
#  'Ashish Sharma': 55,
#  'Edwin Akwanyi': 180,
#  'Peeranat Boontun': 109,
#  'David Kramer': 12,
#  'Morgan Lidman': 10,
#  'Bradley Graham': 97,
#  'Wei Shun Ng': 37,
#  'Soren Toft Hansen': 129,
#  'Fanthhun Estefanos': -10,
#  'Vichayapong Kanjanakeereewong': 82,
#  'Sarath Dunna': 51,
#  'Haukur Gylfi Gislason': -22,
#  'Pascal Souksavat': 12,
#  'Rafael Faria': 96,
#  'Bernardo Atilano': 604,
#  'Louis Beaubois': 96,
#  'Zewei Xie': 91,
#  'Imanhol Navarro Hurtado': -8,
#  'James Jun Hong': 14,
#  'Ryotaro Maruo': 352,
#  'Rafael Colombat Vinent': 10,
#  'Mohd Naser Mansour Nayef': 657,
#  'Chico Aura Dwi Wardoyo': 1147,
#  'Johnathan Akin-Mulrooney': 6,
#  'Alex Lane': 137,
#  'Pacharapol Nipornram': 78,
#  'Salman Abdullah': -1,
#  'Majed Yacine Balahoune': 213,
#  'Wisnu Yuli Prasetyo': 965,
#  'Afatareki Mckenzie': 0,
#  'Daniel Esteban Dieguez Escobar': 25,
#  'Harshit Aggarwal': 629,
#  'Wooi Yik Soh': 311,
#  'Riyanto Subagja': 237,
#  'Lu Guangzu': 445,
#  'Dimitri Han': 12,
#  'Muhammad Bayu Pangisthu': 840,
#  'Peter Lang': 56,
#  'Anjum Bashir': 79,
#  'Michael Fariman': 8,
#  'Chayanin Mekmusik': 83,
#  'Zhang Qi': 127,
#  'Leandro Kesler Lusa': 0,
#  'Kyle Alexander Munoz Seixas': 70,
#  'Ryhor Varabyou': 61,
#  'Kevin Zhang': 113,
#  'Hiripongsathorn Nopparat': 16,
#  'Aneeth Kumar Repudi': 24,
#  'Christopher Grimley': 20,
#  'Vishal Thakran': 4,
#  'Roman Razaki': -16,
#  'Adriano Viale Aguirre': 20,
#  'Yu Jaspar Woon Chai': -8,
#  'Cheam June Wei': 136,
#  'Lucas Constant Da Silva': 10,
#  'Kantawat Leelavechabutr': 890,
#  'Adham Hatem Elgamal': 686,
#  'Zhao Junpeng': 807,
#  'Kiran Kumar Mekala': 172,
#  'Oleksandar Shmundyak': 78,
#  'Yonatan Linarez': 96,
#  'Cao Cuong Pham': 1092,
#  'Samy Khaldi': 228,
#  'Javier Armando Alas': -12,
#  'Kartik Jindal': 553,
#  'Vladimir Malkov': 973,
#  'Christian Lind Thomsen': 106,
#  'Riga Oud': 161,
#  'Yeison Esleiter Del Cid Alvarez': -6,
#  'Diego Mini /': 191,
#  'Seyid Mirjafarov': -25,
#  'Johnnie Torjussen': 90,
#  'En Chia Chang': 4,
#  'Mwansa Rodrick': 4,
#  'Harsheel Dani': 447,
#  'Matias Zamorano Ramos': 16,
#  'Panji Ahmad Maulana': 1688,
#  'Takuma Obayashi': 224,
#  'Patrick Wang': 42,
#  'Ahmetcan Oruc': 147,
#  'Jin Lei Chuang': 148,
#  'Raciel Verdecia Torres': 53,
#  'Thuto Segale': 32,
#  'Birger Abts': 100,
#  'Ruttanapak Oupthong': 304,
#  'Ross Green': 23,
#  'Noh Ju Hong': 18,
#  'Tay Jimmy, Yu Lun': 28,
#  'Adrian George': 222,
#  'Hashiru Shimono': 1004,
#  'Yassine El Mernissi': 176,
#  'Mabo Donald': 4,
#  'Samuel O’Brien Ricketts': 485,
#  'Maxime Moreels': 917,
#  'Mohamed Mostafa Kamel': 414,
#  'Renzo Camogliano Telge': -6,
#  'Sachin Rawat': 134,
#  'Adam Jeffrey': 60,
#  'Jason Anthony Ho-Shue': 1551,
#  'Mihail Rami Panagiotou': -4,
#  'Chan Alan Yun Lung': -2,
#  'N. V. S. Vijetha': 274,
#  'Santiago De La Oliva Alzamora': 16,
#  'Chan Yin Chak': 300,
#  'Jemarey Gordon': 0,
#  'Gianpiero Cavallotti': 10,
#  'Tristan Michael Edison': -4,
#  'Sebastian Andrade': 0,
#  'Jack Hu': 10,
#  'Alberto Alvin Yulianto': 573,
#  'Chen Chi Ting': 644,
#  'Lee Yoon Kyu': 72,
#  'Li Shifeng': 118,
#  'Li Bin Tan': 24,
#  'Edwin Njeri': 75,
#  'Su Li Yang': 518,
#  'Korakrit Laotrakul': 518,
#  'Joshua Magee': 364,
#  'Andrew Rouse': 76,
#  'Chong Yee Han': 255,
#  'Lars Schaenzler': 513,
#  'Luka Wraber': 869,
#  'Igor Ibrahim': 188,
#  'Suppanyu Avihingsanon': 1743,
#  'Redy Perdana': 61,
#  'Robert Batty': 82,
#  'Antoine Eddy Owona Ndimako': -4,
#  'Kayode Abubakar Mope': 25,
#  'Satinder Malik': 16,
#  'Nima Rostampourlagaldani': 0,
#  'Yosua Yosua': 18,
#  'Mahmoud Montaser Mahmoud': 44,
#  'Jacob Nilsson': 375,
#  'Matthew Abela': 141,
#  'Yee Han Chong': 1088,
#  'Patrick Kinyua Mbogo': 77,
#  'Khosit Phetpradab': 1865,
#  'Gopal Krishna Reddy Dundi': -2,
#  'Howard Shu': 489,
#  'Aidil Sholeh Ali Sadikin': 323,
#  'Serafin Zayas': 116,
#  'Napatarawong Sawasdivanichakorn': 18,
#  'Dmitriy Panarin': 123,
#  'Shreyansh Jaiswal': 692,
#  'Renzo Raul Ortiz Avalos': 10,
#  'Omar Elsayegh': 6,
#  'Abdelrahman Abdelhakim': 462,
#  'Artem Pochtarov': 443,
#  'Peter Hrncar': 21,
#  'Alroy Toney': 27,
#  'Ilias Xanthou': 115,
#  'Tzu Chen Wang': -12,
#  'John Wanyoike': 157,
#  'Jonathan Persson': 936,
#  'Esteban Hurtado Rojas': -24,
#  'Amir Saeed': 71,
#  'Yessine Vydelingum': -26,
#  'Humblers Heymard /': 181,
#  'Nguyen Hai Dang': 392,
#  'Mohammad Salman Khan': 26,
#  'Olamide Adebayo': -16,
#  'Akpa Jerome Ibrahim Agnimel': 59,
#  'Nathaniel Ernestan Sulistyo': 70,
#  'Jun Hao Leong': 893,
#  'Pratul Joshi': 846,
#  'Abdelrahman Kashkal': 46,
#  'Ernesto Reyes': 287,
#  'Anton Kokarev': -1,
#  'Maxim Danchenko': 52,
#  'Arun Kumar Ashok Kumar': 59,
#  'Riichi Takeshita': 938,
#  'Lee Dong Keun': 677,
#  'Alap Mishra': 69,
#  'Fabian Roth': 486,
#  'Sandesh GONDARY': -16,
#  'Murad Ali': 151,
#  'Brice Leverdez': 1776,
#  'Wong Hin Shun': -10,
#  'Satheishtharan Ramachandran': 346,
#  'Karim Musayev': 1,
#  'Viktor Aglinder': -10,
#  'Yan Tuck Chan': 4,
#  'Estanislao Joaquin Othar': 16,
#  'Mads Thøgersen': 257,
#  'Fathurrahman Fauzi': 134,
#  'Georges Julien Paul': 1263,
#  'David Jones': 391,
#  'Tejraj PULTOO': 2,
#  'Dinuka Karunaratna': 588,
#  'Kirill Timofeev': -15,
#  'Huang Yuxiang': 1052,
#  'Haokun Ye': 16,
#  'Lukas Zevl': 189,
#  'Krisda Kolum': 10,
#  'Rio Agustino': -18,
#  'Eduardo Vaz': 78,
#  'Vegard Rikheim': 95,
#  'Anibal Marroquin': 572,
#  'Yufeng Cao': 69,
#  'Jonathan Matias': 319,
#  'Peyo Boichinov': 418,
#  'Lau Yu Leong, Alfred': 10,
#  'Mitchell Wheller': 54,
#  'Valeriy Atrashchenkov': 193,
#  'Melaku Amdebirhanu': -10,
#  'Gergo Pytel': 141,
#  'Thoif Ahmed MOHAMED': -2,
#  'Weng Hongyang': 59,
#  'Teerapat Keawan': 14,
#  'Nikita Agalakov': 86,
#  'Joonas Korhonen': 107,
#  'Emre Lale': 1023,
#  'Rowan Scheurkogel': 133,
#  'Daniel Ojaaar': -14,
#  ...}

# %%
#Create dictionary and event dataframes sorted by date
MS_dict, WS_dict, MD_dict, WD_dict, XD_dict = {},{},{},{},{}

#Create the dataframes for each event
df_MS = df[df['EVENT'] == 'MS'].sort_values(by = 'match_week')
df_WS = df[df['EVENT'] == 'WS'].sort_values(by = 'match_week')
df_MD = df[df['EVENT'] == 'MD'].sort_values(by = 'match_week')
df_WD = df[df['EVENT'] == 'WD'].sort_values(by = 'match_week')
df_XD = df[df['EVENT'] == 'XD'].sort_values(by = 'match_week')

#Split players into winners and losers of a match
df_MS['WINNER'] = df_MS['PLAYERS'].apply(lambda x: split_players(x,0,'s'))
df_MS['LOSER'] = df_MS['PLAYERS'].apply(lambda x: split_players(x,1,'s'))
df_WS['WINNER'] = df_WS['PLAYERS'].apply(lambda x: split_players(x,0,'s'))
df_WS['LOSER'] = df_WS['PLAYERS'].apply(lambda x: split_players(x,1,'s'))
df_MD['WINNER'] = df_MD['PLAYERS'].apply(lambda x: split_players(x,0,'d'))
df_MD['LOSER'] = df_MD['PLAYERS'].apply(lambda x: split_players(x,1,'d'))
df_WD['WINNER'] = df_WD['PLAYERS'].apply(lambda x: split_players(x,0,'d'))
df_WD['LOSER'] = df_WD['PLAYERS'].apply(lambda x: split_players(x,1,'d'))
df_XD['WINNER'] = df_XD['PLAYERS'].apply(lambda x: split_players(x,0,'d'))
df_XD['LOSER'] = df_XD['PLAYERS'].apply(lambda x: split_players(x,1,'d'))

# %%
#Initialize the Ranking dictionaries!
MS_dict = create_event_dict_WL(df_MS)
WS_dict = create_event_dict_WL(df_WS)
MD_dict = create_event_dict_WL(df_MD)
WD_dict = create_event_dict_WL(df_WD)
XD_dict = create_event_dict_WL(df_XD)

# %%
MS_dict = update_win_loss(df_MS,MS_dict)

# %%
# Collect points per player, take in win percentage

# %%
MS_dict
# Out:
# {'Shubham Prajapati': [1, 1],
#  'Femi Bioku': [0, 1],
#  'Joo Ven Soong': [12, 7],
#  'Niels VEENSTRA': [1, 1],
#  'Soo Teck Zhi': [0, 1],
#  'Gilmar Jones': [0, 1],
#  'Manuel Del Rosario Pargas': [0, 2],
#  'Wilmer Daniel Brea Nuñez': [2, 4],
#  'Zvonimir Durkinjak': [7, 7],
#  'Danny Chen': [1, 1],
#  'Wei Chi Liu': [0, 2],
#  'Shabahang Asgari': [0, 1],
#  'Ahmad Ali': [0, 2],
#  'Adam Mubiru': [0, 1],
#  'Bongani Von Bodenstein': [1, 2],
#  'Adam Mendrek': [13, 11],
#  'Thanh Long Truong': [0, 2],
#  'Manuel Mejia': [0, 1],
#  'Chun-Wei Chen': [5, 6],
#  'Rezha Akbar Raja Husain': [0, 2],
#  'Bao Duc Duong': [1, 1],
#  'Mohamed Mahmoud Djitli': [1, 1],
#  'Izak Batalha': [0, 1],
#  'Koki Watanabe': [18, 10],
#  'Adel Hamek': [2, 3],
#  'Javier Macagno': [1, 1],
#  'Victor Alves': [0, 1],
#  'Idrisse Issofo Mossagy': [0, 1],
#  'Alexander Butovetstkiy': [0, 2],
#  'Yonathan Ramlie': [3, 0],
#  'Enrique Iglesia Cordero': [0, 1],
#  'Luke Pearce': [3, 3],
#  'Jose Guevara /': [3, 0],
#  'Ondřej Král': [9, 2],
#  'Kasper Lehikoinen': [2, 3],
#  'Hemanth M.Gowda': [3, 9],
#  'Humblers Heymard': [3, 4],
#  'Khaitmurat Kulmatov': [0, 1],
#  'Kaninpong Yokard': [2, 2],
#  'Soong Joo Ven': [3, 2],
#  'Murat Sen': [3, 2],
#  'Soravis Pijitpalakad': [0, 1],
#  'Mateo Maira': [0, 1],
#  'Fernando Sanhueza': [0, 2],
#  'Aman Kumar': [1, 2],
#  'Elias Bracke': [3, 3],
#  'Peder Søvndal': [2, 2],
#  'Artur Silva Pomoceno': [12, 7],
#  'Farzin Khanjani': [4, 2],
#  'Mattias Wigardt': [0, 2],
#  'Son Wan Ho': [18, 7],
#  'Rajiv Ouseph': [10, 9],
#  'Godwin Olofua': [2, 2],
#  'Tarepa Bourgery': [0, 2],
#  'Facundo Ayala': [1, 1],
#  'Phillips Jap': [2, 2],
#  'Yuki Liu': [0, 1],
#  'Juan Ignacio Segui': [0, 1],
#  'Vincent Medina': [1, 2],
#  'Ko Joon Hyung': [0, 1],
#  'Subhankar Dey': [15, 11],
#  'Mohamad Pairavand': [1, 2],
#  'Nicolas Macias': [2, 6],
#  'Haruki Fukuda': [3, 0],
#  'Heo Kwang Hee': [1, 1],
#  'Thomas Rouxel': [8, 9],
#  'Lin Bing-Wei': [0, 1],
#  'Kalonde Charles': [0, 1],
#  'Leon Jang': [0, 2],
#  'Artem Serpionov': [0, 1],
#  'Kettiya Keoxay': [0, 1],
#  'Clement Krobakpo': [7, 5],
#  'Jiann Shiarng Chiang': [0, 1],
#  'Daisuke Omoto': [0, 1],
#  'Datu Mohd Shah Eizlan Sardik': [2, 5],
#  'Christopher Steeghs': [0, 2],
#  'Chengming Ren': [0, 1],
#  'Arturo Hernandez': [1, 5],
#  'Saul Solis': [0, 1],
#  'Ayila Gwambeh': [0, 1],
#  'Mohamed Amine Guelmaoui': [0, 1],
#  'Kai Ho Tang': [1, 6],
#  'Truong Thanh Long': [2, 1],
#  'Jing Ping Ng': [0, 2],
#  'Christopher Alexander Martinez Salvador': [12, 9],
#  'Robert Mann': [10, 10],
#  'Joel Douse': [2, 2],
#  'Yupeng Bai': [4, 3],
#  'Mohammed Almashaekhi': [0, 1],
#  'Sajan Krishna Tamrakar': [0, 1],
#  'Dimitar Yanakiev': [1, 4],
#  'Liu Wei Chi': [0, 4],
#  'Cheng Phorrom': [0, 1],
#  'Naoki Yamazawa': [4, 6],
#  'Brian Yang': [7, 3],
#  'Li Xiang': [0, 1],
#  'Haidar M. Besha': [1, 1],
#  'Akito Homma': [0, 1],
#  'Mitchel Wongsodikromo': [1, 1],
#  'Remi Rossi': [6, 2],
#  'Walid Belaidene': [0, 1],
#  'Christopher Paul': [4, 5],
#  'Noppanai Singrueang': [4, 9],
#  'Stanislav Pukhov': [4, 1],
#  'Hussein Zayan Shaheed': [1, 5],
#  'Sergey Sirant': [7, 9],
#  'Kim Min Ki': [3, 1],
#  'Nikolai Baranov': [0, 1],
#  'Blagovest Kisyov': [0, 1],
#  'Rodolfo Ramirez': [1, 2],
#  'Karono Suwarno': [3, 3],
#  'Kevin Arokia Walter': [0, 1],
#  'Peter Correl': [0, 1],
#  'Abdul Bari Ansari': [0, 1],
#  'Abhishek Kulkarni': [0, 1],
#  'Christoffer Elbrønd': [1, 1],
#  'Sebastian Martinez Cardoso': [1, 1],
#  'Giap Chin Goh': [14, 8],
#  'Daniel Steyn': [0, 1],
#  'Arturo Joel Angeles Garcia': [0, 1],
#  'Armin Zakizadeh': [1, 1],
#  'Kanta Tsuneyama': [17, 8],
#  'Moustafa Bumpenje': [0, 1],
#  'Davies Senono': [1, 3],
#  'Phillipe Charron': [0, 1],
#  'Jarred Elliot': [0, 1],
#  'Hin Shun Wong': [4, 6],
#  'Mohsen Masoumitabarzanjani': [1, 1],
#  'Anton Ivanov': [0, 2],
#  'Vinicius Oliveira Silva': [0, 1],
#  'Gabriel Urteaga Hammond': [0, 1],
#  'Orkhan Galandarov': [1, 5],
#  'Ajay Jayaram': [6, 10],
#  'Rudolf Dellenbach': [7, 6],
#  'Miguel Rocha': [0, 1],
#  'Kemar Valentine': [1, 1],
#  'Amit Sharma': [0, 1],
#  'Tony Wang': [0, 1],
#  'Kirk Francis': [0, 1],
#  'Edwin Ekiring': [3, 2],
#  'Purevsuren Enkhmandakh': [0, 1],
#  'Takuma Ueda': [6, 8],
#  'Mitthren Raj Veerappen': [0, 1],
#  'Adi Pratama': [2, 0],
#  'Heinoa Deane': [0, 2],
#  'Nicardo Reid': [1, 1],
#  'Lucas Claerbout': [13, 7],
#  'Alfonso Garcia-Rosell': [0, 1],
#  'Francielton Farias': [0, 1],
#  'Anthony Murillo': [0, 2],
#  'Lin Chun-Yi': [7, 1],
#  'Pawel Pradzinski': [1, 4],
#  'Diego Castillo': [0, 2],
#  'Chang En Chia': [1, 5],
#  'Jun Yan Ng': [2, 4],
#  'Tan Muhammad Elaf Wei': [0, 2],
#  'Bryan Rodrigo Roque Caycho': [1, 2],
#  'Lau Yu Ming, Adam': [0, 1],
#  'Wesley Caulkett': [3, 0],
#  'Jean Bernard BONGOUT': [0, 1],
#  'Sungwook Hyun': [0, 1],
#  'Yunusa Momoh': [0, 1],
#  'Jack Jiang': [0, 3],
#  'Mikhail Ghelashvili': [1, 1],
#  'Supakit Jandara': [0, 1],
#  'Peter Roenn Stensaeth': [1, 4],
#  'Thammasin Sitthikom': [10, 3],
#  'Anatoliy Yartsev': [7, 5],
#  'Joao Marcos Moreira': [0, 2],
#  'Francisco Brandao': [0, 1],
#  'Muhammad Lukman Hakim Mohd Ibrahim': [2, 4],
#  'Mestapaha Kessari': [1, 0],
#  'Lukas Osele': [2, 4],
#  'Cristian Savin': [5, 5],
#  'Kuo Ching-Hung': [1, 2],
#  'Mehran Shahbazi': [4, 2],
#  'Kim Dong Wook': [0, 1],
#  'Ramadhani Zulkifli': [0, 1],
#  'Sandeep Perumalla': [0, 1],
#  'Rauhiri Goguenheim': [0, 1],
#  'Jack Wang': [1, 2],
#  'Sony Dwi Kuncoro': [8, 5],
#  'Bodhit Joshi': [8, 7],
#  'Parham Khanzadeh': [0, 1],
#  'Aidan Karati': [2, 2],
#  'Eetu Heino': [14, 8],
#  'Dewantoro Pandu': [3, 2],
#  'Khabir TEELUCK': [1, 1],
#  'Mustaopha Muhammed': [0, 1],
#  'Kentaro Hoshino': [2, 1],
#  'Hongyang Weng': [1, 0],
#  'SAI WUU PHET @ Sai Lin Tun Aung': [2, 0],
#  'Kunlavut Vitidsarn': [11, 7],
#  'Sai Praneeth B.': [20, 8],
#  'Darel SOPHIE': [1, 1],
#  'Morne De Beer': [0, 1],
#  'Woo Seung Hoon': [1, 1],
#  'Yang Chih Hsun': [0, 1],
#  'Lee Chia Hao': [3, 0],
#  'David Bjarni Bjornsson': [0, 1],
#  'Victor Odra Munga': [0, 1],
#  'Yong Sheng Lin': [0, 1],
#  'Amir Khamidulin': [0, 1],
#  'Christopher Skrzeba': [0, 1],
#  'Kai Schaefer': [6, 9],
#  'Minoru Koga': [3, 1],
#  'Filip Suwanphingkha': [0, 1],
#  'Patrick Hii': [0, 1],
#  'Artyom Savatyugin': [2, 6],
#  'Xiaodong Sheng': [6, 1],
#  'Leodannis Martinez Palacio': [5, 2],
#  'Cristobal Conejero': [0, 1],
#  'Vega Vio Nirwanda': [15, 8],
#  'Tommy Sugiarto': [20, 9],
#  'Raul Blondet Martinez': [1, 3],
#  'Yu-Hua Lai': [0, 2],
#  'Phone Pyae Naing': [0, 2],
#  'Edward Lau': [2, 3],
#  'Kevin Lee': [0, 1],
#  'Mateus Carrijo Cutti': [4, 3],
#  'Amir Ghasemi': [0, 1],
#  'Mohamed Abdelaziz Ouchefoun': [2, 1],
#  'Iztok Utrosa': [1, 1],
#  'Felipe Roberto Mendes Ribeiro': [2, 1],
#  'Chen Long': [17, 2],
#  'Enis Sesalan': [3, 4],
#  'Dillan Kyle Schaap': [0, 1],
#  'Bruno Barrueto Deza': [3, 7],
#  'Joshua Eipe': [2, 1],
#  'Irfan Ali Bhadusha Abdul Vahab': [1, 1],
#  'Habeeb Temitope Bello': [5, 1],
#  'Sitthikom Thammasin': [4, 3],
#  'Alfred Wong': [0, 1],
#  'Mohammed Hasan': [0, 1],
#  'Chu Han Chou': [2, 1],
#  'Kodai Naraoka': [11, 6],
#  'Elias Nicolaou': [0, 2],
#  'Sabuhi Huseynov': [1, 2],
#  'Wan Mohd Hidayat Wan Hassan': [0, 3],
#  'Jack Boyle': [0, 1],
#  'Chuang Jin Lei': [1, 2],
#  'Mihkel Laanes': [0, 4],
#  'Jamal Jared Ronaldo Thijssen': [0, 1],
#  'Muhammad Sufiyuddin Mohamed Shafei': [3, 2],
#  'Roberto Carlos Herrera Vazquez': [0, 1],
#  'Jang Hyun Seok': [0, 1],
#  'Jan Frohlich': [4, 2],
#  'Yifan Zhang': [0, 1],
#  'Luís Enrique Peñalver': [9, 10],
#  'Muhammad Muqeet Tahir': [1, 1],
#  'Marc Zwiebler': [6, 8],
#  'Yazgan Calisir': [0, 1],
#  'Siril Verma': [8, 11],
#  'Burty James Molia': [2, 2],
#  'Gilles Allet': [0, 1],
#  'Amrullo Bakhshullaev': [1, 3],
#  'Erfan Sharghipour': [0, 1],
#  'Isaac Senfuka': [0, 2],
#  'Huang Guoxing': [1, 1],
#  'Wee Peng SIM': [1, 1],
#  'Topsy Phiri': [1, 2],
#  'Expedito Emuddu': [0, 1],
#  'Soren Opti': [6, 7],
#  'Raffick Alfonso': [0, 1],
#  'Mark Banda': [0, 1],
#  'Muhammad Syafiq Iqbal Mohd Nadzri': [0, 2],
#  'Yeoh Seng Zoe': [0, 1],
#  'Kim Yong Hyun': [0, 1],
#  'Thomas Rouglios': [0, 1],
#  'Vinson Chiu': [1, 2],
#  'Santiago Otero': [1, 2],
#  'Soobhan AJMEER': [0, 1],
#  'Daniel Nikolov': [4, 3],
#  'Tshimologo Rasta': [0, 1],
#  'Leong Jun Hao': [1, 1],
#  'Enzo Sugiura': [1, 2],
#  'Evan Lee': [1, 1],
#  'Collins Valentine FILIMON': [2, 0],
#  'Huang Da Wei': [1, 1],
#  'Sai Wuu Phet @ Sai Lin Tun Aung': [0, 1],
#  'Eizlan Shah Misfahul Muneer': [0, 2],
#  'Nicholas Bonkowsky': [0, 10],
#  'Raymond Webster': [0, 1],
#  'Kevin Barkman': [1, 5],
#  'Bjorn Seguin': [5, 7],
#  'Romain Frank': [0, 1],
#  'Jhotiswaran KARUPATHEVAN': [2, 0],
#  'Hans-Kristian Vittinghus': [3, 0],
#  'Fred Kirabo': [2, 4],
#  'Yodsakorn Nualnooplong': [1, 3],
#  'Fahmi Aulia Rahman': [0, 1],
#  'Labieb Muhzafar Lakamagi': [2, 2],
#  'Leonardo Isa': [0, 2],
#  'Wei Nan': [7, 16],
#  'Angel Argenis Marinez Ulloa': [0, 3],
#  'Sİnan Zorlu': [0, 2],
#  'Bouksani Abderrahim': [0, 1],
#  'Jahid Alhasanov': [0, 2],
#  'Siddharth Jakhar': [1, 1],
#  'Ali Hosseinkhani': [0, 2],
#  'Tianyi Xie': [0, 1],
#  'Kevin Yao Lin Zou': [1, 1],
#  'Gunzorig Enkhjargal': [0, 1],
#  'Vinicius Alecrim Paula': [1, 2],
#  'Nicolas Lenggenhager': [0, 1],
#  'Shesar Hiren Rhustavito': [20, 10],
#  'Luis Martinez': [0, 1],
#  'Ronan Ho-Yagues': [0, 2],
#  'Vladimir Shipilenko': [0, 2],
#  'Arintap Das Gupta': [0, 2],
#  'Jatoonah Ashley': [0, 1],
#  'Bagas Kristianto Nugroho': [2, 3],
#  'Ahmed Nibal': [1, 2],
#  'Osleni Guerrero': [23, 3],
#  'Chee Foong Lim': [1, 2],
#  'Soroush Eskandari Vatannejad': [3, 2],
#  'Koh Jia Wei Joel': [0, 1],
#  'Vannthoun Vath': [0, 1],
#  'Alireza Qasemi': [0, 2],
#  'Tlamelang Kepaletswe': [0, 1],
#  'Felix Burestedt': [4, 6],
#  'Shi Xuan Dominic Soh': [5, 6],
#  'Bence Pytel': [0, 1],
#  'Dean Bencha Wijaya': [0, 1],
#  'Lin Dan': [16, 5],
#  'Andrey Parakhodin': [0, 3],
#  'Yusuf Ramazan Bay': [1, 3],
#  'Koji Naito': [2, 5],
#  'Tanongsak Saensomboonsuk': [16, 13],
#  'Hasan Motaghi': [0, 2],
#  'Donnians Oliveira': [0, 2],
#  'Vi Hen Tan': [0, 1],
#  'Gurusaidutt R. M. V.': [6, 1],
#  'Nonpakorn Nantatheero': [0, 1],
#  'Lautaro Vosylius': [0, 1],
#  'Steven Lesourd': [0, 2],
#  'Naim Mohammed': [0, 2],
#  'Chet Vin Wong': [3, 4],
#  'Raouf Lamrani': [0, 1],
#  'Zhe Ming Nigel Yap': [0, 1],
#  'Janson Trinh': [0, 1],
#  'Kaizar Bobby Alexander': [0, 1],
#  'Anders Antonsen': [19, 7],
#  'Miguel Marinez': [0, 1],
#  'Jose Carlos Suarez Ataury': [0, 1],
#  'Michal Rogalski': [6, 5],
#  'Andi Fadel Muhammad': [4, 3],
#  'Kai Chen Teoh': [3, 2],
#  'Nazareno Ayala': [0, 1],
#  'Vilson Vattanirappel': [1, 6],
#  'Marius Myhre': [2, 5],
#  'Kristofer Darri Finnsson': [0, 1],
#  'R. M. V. Gurusaidutt': [0, 1],
#  'Douglas Lidman': [0, 1],
#  'Gu Junfeng': [1, 0],
#  'Muzafar Lubega': [1, 1],
#  'Khuvituguldur Byambajav': [1, 1],
#  'Chuan-En Hu': [0, 1],
#  'Danilo Peralez': [0, 1],
#  'Dwayne Watson': [0, 1],
#  'Dang Quang Huy': [0, 1],
#  'Timothy Kafunda': [0, 1],
#  'Fabio Caponio': [8, 8],
#  'Hung Chun Chung': [1, 3],
#  'Yang Chih Chieh': [8, 3],
#  'Mega Ciputra': [1, 1],
#  'Zulfadli Zulkiffli': [11, 10],
#  'Shoaib Riaz': [1, 1],
#  'Vladimir Nikulov': [0, 1],
#  'Phanuwat Srimanta': [0, 4],
#  'Srijan Konchada': [2, 3],
#  'Liu Haichao': [2, 4],
#  'Mathias Pedersen': [1, 1],
#  'Minh Bao': [0, 1],
#  'Iskandar Zulkarnain': [11, 4],
#  'Toby Penty': [9, 6],
#  'Masoud Piroozi': [1, 2],
#  'Yun Kyu Lee': [0, 2],
#  'Sachin Dias': [3, 2],
#  'Yulianto Ilham Sri': [4, 5],
#  'Massinissa Temine': [0, 1],
#  'Bradley Pilgrim': [0, 1],
#  'Oscar Lin': [1, 2],
#  'Kalle Koljonen': [16, 10],
#  'Abdelhalim Atout': [0, 1],
#  'Sebastian De La Torre': [0, 2],
#  'Prakash Vijayanath': [0, 2],
#  'Manula Peires': [0, 2],
#  'Kento Saeki': [0, 1],
#  'Muhammad Ziyad Md Tah': [1, 2],
#  'Koki Yamada': [1, 1],
#  'Manuel Vazquez': [0, 4],
#  'Hu Chuan-En': [4, 1],
#  'Varot Uraiwong': [0, 1],
#  'Mayank Ahuja': [1, 2],
#  'Mohamed Ajfan Rasheed': [1, 1],
#  'Giap Chin GOH': [2, 0],
#  'Dino Delmastro': [2, 3],
#  'Jason FRANCOIS': [1, 1],
#  'Peter Yan': [5, 2],
#  'Seung Jae Seo': [0, 1],
#  'Anton Kaisti': [4, 5],
#  'Pierrick Cajot': [7, 2],
#  'Luka Milic': [0, 1],
#  'Daniel Philip': [0, 1],
#  'Kanishq M': [0, 1],
#  'Jaromir Janacek': [2, 8],
#  'Vladimir Rusin': [0, 1],
#  'Hong Ji Hoon': [1, 1],
#  'Albert Myles': [0, 1],
#  'Daniel Ferrer Cepero': [1, 1],
#  'Kidambi Srikanth': [17, 2],
#  'Rasmus Messerschmidt': [5, 5],
#  'Yu Jiahao': [0, 1],
#  'Qiao Bin': [8, 8],
#  'Tobias Kuenzi': [2, 0],
#  'Armando Gaitan': [1, 2],
#  'Murad Bayramov': [0, 1],
#  'Viktor Axelsen': [9, 5],
#  'Samuel Ho': [1, 1],
#  'Kenta Nishimoto': [12, 8],
#  'Younes Hafouz': [0, 1],
#  'Jacob Musisi': [1, 4],
#  'Denis Grachev': [3, 5],
#  'Manish Gupta': [0, 1],
#  'Angel Herrera Rodríguez': [5, 1],
#  'Emmanuel Yaw Donkor': [7, 3],
#  'Herbert Ebayo': [1, 4],
#  'Daniel Chislov': [3, 2],
#  'Oscar Guo': [6, 2],
#  'Yann Zaccaria': [0, 1],
#  'Buwaneka Goonethilleka': [4, 1],
#  'Shane Wilson': [1, 1],
#  'Mohamed Abderrahime Belarbi': [4, 3],
#  'Thierry BELLEPEAU': [0, 1],
#  'Kiran Raj Maniraj': [0, 1],
#  'Chen Yen Chun': [1, 1],
#  'Chun Chung Hung': [0, 2],
#  'Paulin Nguele Biya': [1, 1],
#  'Ye Binghong': [3, 2],
#  'Zulficar Issufo Mussagy': [0, 1],
#  'Ethan Chen': [0, 1],
#  'Pablo Sanchez': [0, 2],
#  'William Cabrera': [3, 4],
#  'Ruben Castellanos': [4, 3],
#  'Yi Xin Chew': [0, 1],
#  'Jaspar Woon Chai Yu': [1, 7],
#  'Shahzan Shah Misfahul': [1, 3],
#  'Abbas Alpofead': [0, 1],
#  'Hermansyah .': [2, 0],
#  'Georgii Karpov': [3, 3],
#  'Alex Patrick Zolobe': [2, 1],
#  'Otsile Marumo': [1, 1],
#  'Julien Carraggi': [1, 0],
#  'Koceila Mammeri': [0, 3],
#  'Alireza Faghfouri': [0, 1],
#  'Orijit Chaliha': [0, 1],
#  'Bons Vincent': [0, 1],
#  'Gergely Krausz': [12, 12],
#  'Duarte Nuno Anjo': [17, 10],
#  'Jia Wei Joel Koh': [0, 1],
#  'Dakeil Jonathan Thorpe': [0, 3],
#  'Ahmed Amine Ksikes': [0, 2],
#  'Lucas Mitchell': [1, 1],
#  'Georges Julien PAUL': [2, 0],
#  'June Wei Cheam': [20, 7],
#  'Timothy Lam': [2, 3],
#  'David Kim': [4, 0],
#  'Awais Zahid': [1, 1],
#  'Alden Lefilson Putra Mainaky': [0, 1],
#  'Matheus Voigt': [1, 2],
#  'Kim Bruun': [12, 7],
#  'Batdavaa Munkhbat': [2, 1],
#  'Calvin Lin': [0, 2],
#  'Lin Chia Hsuan': [13, 7],
#  'Ryan Tong': [0, 3],
#  'Yim Jong Woo': [1, 1],
#  'Chayanin Susasin': [0, 1],
#  'Abhishek Yeligar': [0, 2],
#  'Aryamann Tandon': [5, 4],
#  'Jacob Schueler': [4, 5],
#  'Bilal Elharab': [1, 1],
#  'Matthew Lee': [2, 2],
#  'Jacob Maliekal': [3, 5],
#  'Lu Chen': [1, 1],
#  'Alonso Medel /': [2, 1],
#  'Fabricio Farias': [11, 4],
#  'Gerelsukh Jargalsaikhan': [0, 1],
#  'Rahul Yadav Chittaboina': [10, 11],
#  'Ernesto Velazquez': [2, 0],
#  'Zin Rei Ryan Ng': [5, 5],
#  'Joyireh Avi Manasye': [1, 1],
#  'Yang Shen': [2, 1],
#  'Sayed Imran Meri': [0, 1],
#  'Naohiro Matsukawa': [1, 1],
#  'Hock Lai Lee': [2, 3],
#  'Muhammad Aiman Abd Malek': [0, 1],
#  'Rory Easton': [0, 1],
#  'Alireza Karami': [1, 2],
#  'Thanapat Rungrattanapon': [0, 1],
#  'Sourabh Varma': [3, 1],
#  'Sebastian Contró': [1, 2],
#  'Che Alexander Beckford': [0, 1],
#  'Mario Cuba': [0, 1],
#  'Muhammad Febriansyah': [1, 2],
#  'Sai Charan Koya': [0, 1],
#  'Michael Opoku Baah': [1, 2],
#  'Ahmed Salah': [6, 4],
#  'Prannoy H. S.': [22, 9],
#  'Lee Chak Wai': [0, 2],
#  'Joshua Jian Min Khong': [0, 1],
#  'Yik Fong Lim': [0, 1],
#  'Siddharath Thakur': [8, 10],
#  'Noval Ramadhan': [1, 1],
#  'Faiz Rozain': [6, 4],
#  'Ben Torrance': [0, 1],
#  'Huzair Asraaf Ali BHUTTOO': [0, 1],
#  'Ivan Rusev': [8, 6],
#  'Rüdiger Gnedt': [1, 3],
#  'Osvert Riveron': [2, 1],
#  'Yacine Allou': [0, 1],
#  'Joel König': [1, 4],
#  'Heng Lin Ngan': [2, 4],
#  'David Peng': [1, 5],
#  'Sattawat Pongnairat': [1, 4],
#  'Andrew Zhuang': [0, 1],
#  'Kingsley Nelson': [0, 1],
#  'Rhys Walker': [0, 1],
#  'Niccolo Tagle': [1, 1],
#  'Zhou Zeqi': [8, 4],
#  'Nicolas Oliva': [1, 2],
#  'Kaustubh RAWAT': [0, 1],
#  'Ahmed NIBAL': [1, 1],
#  'Pachaarapol Nipornram': [1, 2],
#  'Fahmi Mubarok': [1, 2],
#  'Hikaru Minegishi': [0, 1],
#  'Christo Popov': [1, 0],
#  'Mohamad Chaharmali': [0, 1],
#  'Mohamad Charmali': [1, 1],
#  'Artur Niyazov': [2, 2],
#  'Joel Findlay': [1, 1],
#  'Karono Karono': [2, 1],
#  'Paul Kopolo': [0, 2],
#  'Denzel Sweet': [0, 1],
#  'Wolfgang Gnedt': [3, 10],
#  'Israel Wanagalya': [1, 1],
#  'Kazumasa Sakai': [10, 8],
#  'Jesus Arturo Barajas Lopez': [0, 1],
#  'Rano Boago': [1, 1],
#  'Krzysztof Jakowczuk': [3, 1],
#  'Lee Hyun Deok': [1, 1],
#  'Antonio Emanuel Ortiz': [0, 1],
#  'Atli Tomasson': [0, 1],
#  'Quentin Filliettaz': [0, 1],
#  'Kieran Merrilees': [7, 9],
#  'Krishna Adi Nugraha': [22, 6],
#  'Said Shahabudin Aini': [0, 1],
#  'Lee Cheuk Yiu': [14, 7],
#  'Said Mohammad Kabir Mirzad': [0, 1],
#  'Joel Angus': [0, 2],
#  'Carlos Daniel Albanes Cordon': [1, 1],
#  'Dzmitry Saidakou': [0, 1],
#  'Wei Feng Chong': [17, 12],
#  'Auston Govender': [0, 1],
#  'Bhaskar Chakraborty': [0, 1],
#  'Mikkel Enghøj': [2, 4],
#  'Zhao Jie Stanley Chiong': [0, 1],
#  'Leo Lee': [0, 1],
#  'Nathan Tang': [4, 4],
#  'Paul-Antoine Dostie-Guindon': [2, 1],
#  'Hannes Gerberich': [0, 3],
#  'Jun Hong Lee': [1, 1],
#  'Azmy Qowimuramadhoni': [2, 2],
#  'Kari Gunnarsson': [2, 2],
#  'Jeppe Bruun': [1, 2],
#  'Fikri Ihsandi Hadmadi': [13, 9],
#  'Muhammad Irfan Saeed Bhatti': [2, 1],
#  'Jimmy, Yu Lun Tay': [0, 6],
#  'Enzi Shafira': [21, 5],
#  'Daniel Lopes Aguilera': [0, 1],
#  'Daniel Hardiana Octavianus': [0, 1],
#  'Jonathan Bing Tsan Lai': [1, 1],
#  'Jasmanjot Virk': [1, 3],
#  'Kazuteru Kozai': [3, 2],
#  'Ignacio Maceiras': [0, 1],
#  'Ailton Josue Correa Martinez': [0, 2],
#  'Vishal Sawaram': [0, 1],
#  'Wang Yuehang': [9, 7],
#  'Pannawit Thongnuam': [22, 13],
#  'Chia Hao Lee': [10, 6],
#  'Misha Zilberman': [22, 15],
#  'Luis Ramon Garrido': [20, 3],
#  'Huzair Asraaf Ali Bhuttoo': [0, 1],
#  'George Priestman': [0, 1],
#  'Matin Moghimi': [0, 1],
#  'Park Sung Min': [2, 1],
#  'Shaquille Palmer': [1, 1],
#  'Zohaib Khan Khalil': [0, 1],
#  'Chen Chun-Wei': [2, 4],
#  'Tan Chun Seang': [0, 1],
#  'Melvin APPIAH': [0, 1],
#  'Sameer Verma': [18, 6],
#  'Hardik Makkar': [1, 2],
#  'Huang Yu Kai': [1, 1],
#  'Tumisang Olekantse': [3, 1],
#  'Kervin Ghislain': [2, 3],
#  'Misbun Ramdan Mohmed Misbun': [0, 1],
#  'Kittipong Imnark': [6, 10],
#  'Ranthushka Sasindu': [2, 1],
#  'Peeranut Sangsomporn': [0, 1],
#  'Chin Yong Chian': [2, 4],
#  'Zach Russ': [4, 3],
#  'Jhotiswaran Karupathevan': [2, 2],
#  'Kittithat Cheiklinthes': [0, 1],
#  'Vincent Cheng Wei Phuah': [0, 6],
#  'Erfan Taran': [1, 1],
#  'Ivan Mayega': [0, 1],
#  'Mahbub Thomi Azizan': [2, 2],
#  'Toma Junior Popov': [10, 4],
#  'Ian Senoga': [0, 1],
#  'Amir Jabbari': [0, 2],
#  'Matteo Bellucci': [2, 7],
#  'Francis Joey Wong': [0, 1],
#  'Hwang Jong Soo': [1, 1],
#  'Cameron Coetzer': [0, 2],
#  'Bai Yupeng': [1, 2],
#  'Daniel La Torre Regal': [11, 12],
#  'Jialanai Luang Amath': [2, 1],
#  'Sherzod Zokhidov': [0, 1],
#  'Zezhou Zhong': [0, 1],
#  'Teklu Endale': [0, 1],
#  'Yu Igarashi': [17, 6],
#  'Philip Illum Klindt': [1, 1],
#  'Niluka Karunaratne': [15, 10],
#  'Richard Kuhl': [1, 2],
#  'Giovanni Toti': [8, 5],
#  'Uriel Francisco Canjura Artiga': [5, 4],
#  'Ryota Ichii': [0, 1],
#  'Nick Fransman': [1, 5],
#  'Liew Daren': [3, 1],
#  'Hu Yun': [12, 16],
#  'Abhinav Manota': [9, 5],
#  'Patrick Abildgaard': [2, 1],
#  'Mads Christophersen': [5, 3],
#  'Tuguldur Boldbaatar': [0, 1],
#  'Siddharth .': [2, 1],
#  'Alexander Kim': [0, 1],
#  'Damien Howell': [1, 3],
#  'Gustavo Morales': [0, 3],
#  'Saran Nopphakao': [1, 1],
#  'Kyle Golding': [0, 2],
#  'Shae Michael Martin': [0, 2],
#  'Teh Jia Heng Jason': [0, 1],
#  'Marcin Nowak': [1, 2],
#  'Wibowo Setyaldi Putra': [0, 1],
#  'Sarim Mohamed': [0, 1],
#  'Soogun Z': [0, 1],
#  'Pham Cao Cuong': [4, 2],
#  'Joshua Feng': [0, 4],
#  'Mitch, Aubrey Nai Chung Tong': [1, 2],
#  'Jason Mann': [1, 1],
#  'Eric Jr Timmerman': [0, 1],
#  'Oscar Sunekær': [0, 1],
#  'Dionysius Hayom Rumbaka': [7, 7],
#  'Zhu Siyuan': [1, 0],
#  'Cory Fanus': [0, 5],
#  'Pollakorn Jarasjindawong': [0, 1],
#  'Pang Fong Pui': [0, 1],
#  'Chanmara Tep': [0, 2],
#  'Anthony Joe': [9, 7],
#  'Riki Nur Fajar Rohman': [0, 1],
#  'Soh Shi Xuan Dominic': [0, 2],
#  'Jose Guevara': [9, 11],
#  'Dong Hoon Kim': [1, 2],
#  'Diego Subauste Tokumura /': [2, 1],
#  'Tsamorena Kgosidialwa': [0, 1],
#  'Kento Momota': [16, 0],
#  'Reimi Starling Cabrera Rosario': [1, 4],
#  'Ricky Cheng': [2, 2],
#  'Mek Narongrit': [8, 7],
#  'Enejoh Abah': [1, 2],
#  'Ridzwan Rahmat': [1, 3],
#  'Ibrahimo Issufo Mussagy': [0, 1],
#  'Saran Jamsri': [10, 6],
#  'Milan Ludik': [9, 13],
#  'Fong Hau Sim': [0, 4],
#  'Tien Minh Nguyen': [18, 9],
#  'Jesper Toft': [3, 1],
#  'Timothy Chiu': [7, 12],
#  'Abdul Karim Hidayat': [0, 3],
#  'Rasmus Gemke': [14, 4],
#  'Hsu Jui Ting': [0, 1],
#  'William Ponsonby': [2, 3],
#  'Kwang Hee Heo': [8, 4],
#  'Datu Mohd Saffuan Nizam Sardik': [2, 3],
#  'Ade Resky Dwicahyo': [4, 3],
#  'Adulrach Namkul': [12, 17],
#  'Ng Ka Long Angus': [23, 6],
#  'Tian Houwei': [4, 9],
#  'Rosario Maddaloni': [24, 13],
#  'Milan Dratva': [6, 10],
#  'Alexey Panov': [0, 1],
#  'Carlos Luna': [1, 2],
#  'Stephan Beeharry': [1, 1],
#  'Alexandr Kozyrev': [2, 2],
#  'Anand Pawar': [4, 3],
#  'Christopher Beecher': [0, 1],
#  'Seong Hyun Son': [0, 1],
#  'Imran Wadia': [0, 1],
#  'Lishwan Mudukasan': [0, 5],
#  'Mevan DEWOO': [0, 1],
#  'Amirabbas Mirbagheri': [0, 1],
#  'Amantle Mosweu': [1, 1],
#  'Septian Dwi Maulana': [0, 1],
#  'Daniel S. Farid': [3, 2],
#  'Vanphason Suvannaphengsy': [0, 1],
#  'John Riad': [0, 1],
#  'Muhammad Izzuddin Shamsul Muzli': [5, 1],
#  'Nhat Nguyen': [7, 1],
#  'Tan Jia Wei': [5, 2],
#  'Aaron Chen': [0, 1],
#  'Ali Ahmed El Khateeb': [1, 0],
#  'Muhammad Syafiq A Sanusi': [1, 1],
#  'Yannick Blondin': [1, 1],
#  'Komandani Maytri Sugiarto': [0, 1],
#  'Francisco Rafael Trevino Buenrostro': [0, 2],
#  'Mohammad Reza Bagheri': [0, 1],
#  'Hermansah .': [6, 0],
#  'Jacob Morgon': [0, 1],
#  'Ashwant Gobinathan': [3, 4],
#  'Ousmane Ouedraogo': [0, 2],
#  'Mohamad Alsawas': [0, 1],
#  'Matthew Yee-Grant': [0, 1],
#  'Sarim MOHAMED': [0, 1],
#  'Leo Rossi': [4, 1],
#  'Kandarp Chaubey': [0, 1],
#  'Mikael Westerback': [0, 1],
#  'Kevin Cordon': [29, 7],
#  'Mukhammad Rizqy Ramadhani': [2, 2],
#  'Kachain Buarung': [2, 3],
#  'Xaysomphone Vongpachith': [0, 1],
#  'Balraj Kajla': [1, 1],
#  'Tejraj Pultoo': [1, 2],
#  'Wandy Luis Roman Gonzalez': [1, 1],
#  'Aljallad Ahmad': [9, 8],
#  'Liang Hua Chun': [1, 1],
#  'Oscar Bansal': [1, 1],
#  'Stamatis Tsigirdakis': [0, 1],
#  'Kalombo Mulenga': [4, 3],
#  'Mateo Pinto': [0, 1],
#  'Ben Perkinson': [0, 2],
#  'Mathias Thyrri': [0, 1],
#  'Mohammed Al-Ibadi': [0, 1],
#  'Parupalli Kashyap': [10, 7],
#  'Alireza Kazemi': [1, 1],
#  'Daniel Sam': [2, 1],
#  'Kayode Samuel Oyeniran': [0, 1],
#  'Rizky Kurniawan': [0, 1],
#  'Koo Takahashi': [0, 1],
#  'Muhammad Rehan Diaz': [1, 3],
#  'Mehdi Ansari': [0, 1],
#  'Thabani Mathe': [2, 3],
#  'Pavel Kotsarenko': [0, 3],
#  'Olonbayar Enkhbat': [0, 1],
#  'Brian Kasirye': [3, 4],
#  'Leon Seiwald': [4, 3],
#  'Ahmad Balarabe Umar': [0, 1],
#  'Auditya Alpha Hidayat': [1, 3],
#  'Hsu Jen Hao': [20, 21],
#  'Taiki Kato': [0, 1],
#  'Rizky Doka Putra': [0, 1],
#  'Matej Hlinican': [5, 10],
#  'Julius Mbewe': [0, 1],
#  'Adam Twardzik': [0, 1],
#  'Quentin Bernaix': [1, 2],
#  'Ricky Liuzhou': [3, 2],
#  'Evert Sukamta': [1, 1],
#  'Mariano Novoa': [0, 3],
#  'Andre Marteen': [11, 10],
#  'Matthew Michel': [0, 1],
#  'Ali Bastani': [0, 2],
#  'Siddharth Pratap Singh': [8, 6],
#  'Perekisi Tshepo': [0, 1],
#  'Bastian Lizama': [0, 2],
#  'Zulhelmi Zulkiffli': [6, 7],
#  'Youssef Hafouz': [0, 1],
#  'Ashish Sharma': [1, 1],
#  'Edwin Akwanyi': [2, 2],
#  'Peeranat Boontun': [1, 2],
#  'David Kramer': [0, 1],
#  'Morgan Lidman': [0, 1],
#  'Bradley Graham': [1, 2],
#  'Wei Shun Ng': [0, 1],
#  'Soren Toft Hansen': [2, 1],
#  'Fanthhun Estefanos': [0, 1],
#  'Vichayapong Kanjanakeereewong': [1, 1],
#  'Sarath Dunna': [1, 1],
#  'Haukur Gylfi Gislason': [0, 1],
#  'Pascal Souksavat': [0, 1],
#  'Rafael Faria': [1, 1],
#  'Bernardo Atilano': [10, 7],
#  'Louis Beaubois': [1, 2],
#  'Zewei Xie': [1, 1],
#  'Imanhol Navarro Hurtado': [0, 1],
#  'James Jun Hong': [0, 1],
#  'Ryotaro Maruo': [5, 3],
#  'Rafael Colombat Vinent': [0, 1],
#  'Mohd Naser Mansour Nayef': [10, 8],
#  'Chico Aura Dwi Wardoyo': [15, 10],
#  'Johnathan Akin-Mulrooney': [0, 1],
#  'Alex Lane': [2, 2],
#  'Pacharapol Nipornram': [1, 1],
#  'Salman Abdullah': [0, 1],
#  'Majed Yacine Balahoune': [3, 1],
#  'Wisnu Yuli Prasetyo': [15, 6],
#  'Afatareki Mckenzie': [0, 1],
#  'Daniel Esteban Dieguez Escobar': [0, 2],
#  'Harshit Aggarwal': [8, 7],
#  'Wooi Yik Soh': [4, 3],
#  'Riyanto Subagja': [2, 6],
#  'Lu Guangzu': [7, 1],
#  'Dimitri Han': [0, 1],
#  'Muhammad Bayu Pangisthu': [12, 4],
#  'Peter Lang': [0, 1],
#  'Anjum Bashir': [1, 1],
#  'Michael Fariman': [0, 1],
#  'Chayanin Mekmusik': [1, 1],
#  'Zhang Qi': [2, 1],
#  'Leandro Kesler Lusa': [0, 2],
#  'Kyle Alexander Munoz Seixas': [1, 4],
#  'Ryhor Varabyou': [0, 1],
#  'Kevin Zhang': [1, 3],
#  'Hiripongsathorn Nopparat': [0, 1],
#  'Aneeth Kumar Repudi': [0, 1],
#  'Christopher Grimley': [0, 1],
#  'Vishal Thakran': [0, 1],
#  'Roman Razaki': [0, 1],
#  'Adriano Viale Aguirre': [0, 1],
#  'Yu Jaspar Woon Chai': [0, 1],
#  'Cheam June Wei': [1, 3],
#  'Lucas Constant Da Silva': [0, 1],
#  'Kantawat Leelavechabutr': [10, 10],
#  'Adham Hatem Elgamal': [9, 6],
#  'Zhao Junpeng': [10, 7],
#  'Kiran Kumar Mekala': [2, 4],
#  'Oleksandar Shmundyak': [0, 2],
#  'Yonatan Linarez': [1, 1],
#  'Cao Cuong Pham': [17, 8],
#  'Samy Khaldi': [3, 1],
#  'Javier Armando Alas': [0, 1],
#  'Kartik Jindal': [6, 9],
#  'Vladimir Malkov': [13, 8],
#  'Christian Lind Thomsen': [1, 2],
#  'Riga Oud': [2, 2],
#  'Yeison Esleiter Del Cid Alvarez': [0, 1],
#  'Diego Mini /': [3, 0],
#  'Seyid Mirjafarov': [0, 1],
#  'Johnnie Torjussen': [0, 3],
#  'En Chia Chang': [1, 1],
#  'Mwansa Rodrick': [0, 1],
#  'Harsheel Dani': [7, 6],
#  'Matias Zamorano Ramos': [0, 3],
#  'Panji Ahmad Maulana': [26, 13],
#  'Takuma Obayashi': [1, 4],
#  'Patrick Wang': [0, 1],
#  'Ahmetcan Oruc': [1, 2],
#  'Jin Lei Chuang': [0, 5],
#  'Raciel Verdecia Torres': [1, 1],
#  'Thuto Segale': [1, 1],
#  'Birger Abts': [1, 2],
#  'Ruttanapak Oupthong': [2, 5],
#  'Ross Green': [0, 2],
#  'Noh Ju Hong': [0, 1],
#  'Tay Jimmy, Yu Lun': [0, 1],
#  'Adrian George': [3, 3],
#  'Hashiru Shimono': [12, 10],
#  'Yassine El Mernissi': [2, 2],
#  'Mabo Donald': [0, 3],
#  'Samuel O’Brien Ricketts': [6, 4],
#  'Maxime Moreels': [13, 8],
#  'Mohamed Mostafa Kamel': [4, 5],
#  'Renzo Camogliano Telge': [0, 1],
#  'Sachin Rawat': [2, 4],
#  'Adam Jeffrey': [1, 3],
#  'Jason Anthony Ho-Shue': [22, 10],
#  'Mihail Rami Panagiotou': [0, 1],
#  'Chan Alan Yun Lung': [0, 1],
#  'N. V. S. Vijetha': [2, 6],
#  'Santiago De La Oliva Alzamora': [0, 1],
#  'Chan Yin Chak': [2, 5],
#  'Jemarey Gordon': [0, 1],
#  'Gianpiero Cavallotti': [0, 1],
#  'Tristan Michael Edison': [0, 1],
#  'Sebastian Andrade': [0, 1],
#  'Jack Hu': [0, 1],
#  'Alberto Alvin Yulianto': [7, 5],
#  'Chen Chi Ting': [7, 7],
#  'Lee Yoon Kyu': [1, 1],
#  'Li Shifeng': [2, 0],
#  'Li Bin Tan': [0, 1],
#  'Edwin Njeri': [1, 1],
#  'Su Li Yang': [6, 3],
#  'Korakrit Laotrakul': [4, 10],
#  'Joshua Magee': [5, 6],
#  'Andrew Rouse': [0, 4],
#  'Chong Yee Han': [4, 2],
#  'Lars Schaenzler': [4, 12],
#  'Luka Wraber': [10, 9],
#  'Igor Ibrahim': [2, 2],
#  'Suppanyu Avihingsanon': [25, 11],
#  'Redy Perdana': [1, 2],
#  'Robert Batty': [1, 1],
#  'Antoine Eddy Owona Ndimako': [0, 1],
#  'Kayode Abubakar Mope': [0, 1],
#  'Satinder Malik': [0, 1],
#  'Nima Rostampourlagaldani': [0, 2],
#  'Yosua Yosua': [0, 3],
#  'Mahmoud Montaser Mahmoud': [1, 1],
#  'Jacob Nilsson': [5, 3],
#  'Matthew Abela': [2, 1],
#  'Yee Han Chong': [13, 8],
#  'Patrick Kinyua Mbogo': [1, 1],
#  'Khosit Phetpradab': [27, 10],
#  'Gopal Krishna Reddy Dundi': [0, 1],
#  'Howard Shu': [6, 4],
#  'Aidil Sholeh Ali Sadikin': [4, 3],
#  'Serafin Zayas': [1, 3],
#  'Napatarawong Sawasdivanichakorn': [0, 1],
#  'Dmitriy Panarin': [2, 1],
#  'Shreyansh Jaiswal': [9, 9],
#  'Renzo Raul Ortiz Avalos': [0, 1],
#  'Omar Elsayegh': [0, 1],
#  'Abdelrahman Abdelhakim': [5, 5],
#  'Artem Pochtarov': [6, 7],
#  'Peter Hrncar': [0, 1],
#  'Alroy Toney': [0, 1],
#  'Ilias Xanthou': [0, 6],
#  'Tzu Chen Wang': [0, 1],
#  'John Wanyoike': [2, 2],
#  'Jonathan Persson': [14, 3],
#  'Esteban Hurtado Rojas': [0, 1],
#  'Amir Saeed': [1, 1],
#  'Yessine Vydelingum': [0, 1],
#  'Humblers Heymard /': [2, 1],
#  'Nguyen Hai Dang': [5, 2],
#  'Mohammad Salman Khan': [0, 2],
#  'Olamide Adebayo': [0, 1],
#  'Akpa Jerome Ibrahim Agnimel': [1, 2],
#  'Nathaniel Ernestan Sulistyo': [1, 12],
#  'Jun Hao Leong': [15, 4],
#  'Pratul Joshi': [11, 9],
#  'Abdelrahman Kashkal': [1, 2],
#  'Ernesto Reyes': [5, 4],
#  'Anton Kokarev': [0, 1],
#  'Maxim Danchenko': [0, 1],
#  'Arun Kumar Ashok Kumar': [1, 7],
#  'Riichi Takeshita': [13, 6],
#  'Lee Dong Keun': [8, 8],
#  'Alap Mishra': [0, 2],
#  'Fabian Roth': [8, 2],
#  'Sandesh GONDARY': [1, 1],
#  'Murad Ali': [2, 2],
#  'Brice Leverdez': [23, 16],
#  'Wong Hin Shun': [0, 1],
#  'Satheishtharan Ramachandran': [5, 5],
#  'Karim Musayev': [0, 1],
#  'Viktor Aglinder': [0, 1],
#  'Yan Tuck Chan': [0, 6],
#  'Estanislao Joaquin Othar': [0, 1],
#  'Mads Thøgersen': [4, 2],
#  'Fathurrahman Fauzi': [1, 2],
#  'Georges Julien Paul': [19, 5],
#  'David Jones': [3, 5],
#  'Tejraj PULTOO': [0, 1],
#  'Dinuka Karunaratna': [8, 5],
#  'Kirill Timofeev': [0, 1],
#  'Huang Yuxiang': [11, 13],
#  'Haokun Ye': [0, 1],
#  'Lukas Zevl': [1, 6],
#  'Krisda Kolum': [0, 1],
#  'Rio Agustino': [0, 1],
#  'Eduardo Vaz': [1, 1],
#  'Vegard Rikheim': [1, 1],
#  'Anibal Marroquin': [11, 5],
#  'Yufeng Cao': [1, 1],
#  'Jonathan Matias': [2, 4],
#  'Peyo Boichinov': [4, 5],
#  'Lau Yu Leong, Alfred': [0, 1],
#  'Mitchell Wheller': [0, 2],
#  'Valeriy Atrashchenkov': [3, 2],
#  'Melaku Amdebirhanu': [0, 1],
#  'Gergo Pytel': [2, 2],
#  'Thoif Ahmed MOHAMED': [0, 1],
#  'Weng Hongyang': [0, 1],
#  'Teerapat Keawan': [1, 1],
#  'Nikita Agalakov': [1, 1],
#  'Joonas Korhonen': [1, 2],
#  'Emre Lale': [16, 6],
#  'Rowan Scheurkogel': [1, 3],
#  'Daniel Ojaaar': [0, 1],
#  ...}

# %%
for game in df['SCORES'].apply(lambda x: player_point_split(x))[0]:
    scores = game.split('-')
    print(int(scores[0]))
    print(int(scores[1]))
# Out:
# 21
# 14
# 22
# 20

# %%
df['WINNER POINTS'] = df['SCORES'].apply(lambda x: player_point_split(x,1))
df['LOSER POINTS'] = df['SCORES'].apply(lambda x: player_point_split(x,2))
df['WINNER +-'] = df['SCORES'].apply(lambda x: player_point_split(x,3))
df['LOSER +-'] = df['SCORES'].apply(lambda x: player_point_split(x,4))

# %%
df.head()
# Out:
#                                              PLAYERS  \
# 0                  ['Jacob Nilsson', 'Kai Schaefer']
# 1            ['Sabrina Jaquet', 'Natalia Perminova']
# 2  ['Rodion Alimov', 'Alina Davletova', 'Ben Lane...
# 3  ['Marcus Ellis [3]', 'Lauren Smith', 'Robin Ta...
# 4  ['Bastian Kersaudy', 'Lea Palermo', 'Jelle Maa...
#
#                                   COUNTRIES                       SCORES  \
# 0                      ['[SWE] ', '[GER] ']           ['21-14', '22-20']
# 1                      ['[SUI] ', '[RUS] ']  ['21-17', '13-21', '21-17']
# 2  ['[RUS] ', '[RUS] ', '[ENG] ', '[ENG] ']           ['21-19', '27-25']
# 3  ['[ENG] ', '[ENG] ', '[NED] ', '[NED] ']  ['17-21', '21-11', '21-15']
# 4  ['[FRA] ', '[FRA] ', '[NED] ', '[NED] ']           ['23-21', '21-12']
#
#   EVENT match_week  WINNER POINTS  LOSER POINTS  WINNER +-  LOSER +-
# 0   MS    20180424             43            34          9        -9
# 1   WS    20180424             55            55          0         0
# 2   XD    20180424             48            44          4        -4
# 3   XD    20180424             59            47         12       -12
# 4   XD    20180424             44            33         11       -11
